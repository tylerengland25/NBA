# %% [markdown]
# # Rebounds

# %%
import os
import pandas as pd
import numpy as np
import scipy.stats as stats
from unidecode import unidecode
from datetime import date

# %%
os.chdir('/home/tylerengland/NBA')
os.getcwd()
# Out:
# '/home/tylerengland/NBA'

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('backend/data/details/game_details.csv')

# %%
df.head()
# Out:
#                 date        visitor        home  team  starter        player  \
# 0  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0  Kirk Hinrich
# 1  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0   Ben Wallace
# 2  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0     Luol Deng
# 3  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0    Ben Gordon
# 4  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0    P.J. Brown
#
#          mp    fg   fga  fg_perc  ...  drb   trb  ast  stl  blk  tov   pf  \
# 0  34:38:00  10.0  18.0    0.556  ...  4.0   4.0  3.0  2.0  0.0  0.0  2.0
# 1  28:29:00   2.0   5.0    0.400  ...  5.0  11.0  1.0  0.0  1.0  0.0  2.0
# 2  24:07:00   4.0   9.0    0.444  ...  1.0   2.0  1.0  1.0  0.0  3.0  2.0
# 3     22:56   1.0   9.0    0.111  ...  1.0   1.0  2.0  1.0  0.0  2.0  3.0
# 4     18:23   1.0   2.0    0.500  ...  3.0   3.0  1.0  1.0  1.0  2.0  3.0
#
#     pts  plus_minus  season
# 0  26.0        23.0     NaN
# 1   5.0        13.0     NaN
# 2  12.0         8.0     NaN
# 3   6.0         7.0     NaN
# 4   4.0        15.0     NaN
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['date', 'visitor', 'home', 'team', 'starter', 'player', 'mp', 'fg',
#        'fga', 'fg_perc', '3p', '3pa', '3p_perc', 'ft', 'fta', 'ft_perc', 'orb',
#        'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'plus_minus',
#        'season'],
#       dtype='object')

# %% [markdown]
# Drop duplicates and NA's

# %%
df.drop_duplicates(subset=['date', 'visitor', 'home', 'team', 'player'], inplace=True)

# %%
df.dropna(subset = ['player'], inplace = True)

# %%
df.isna().sum()
# Out:
# date               0
# visitor            0
# home               0
# team               0
# starter            0
# player             0
# mp                 0
# fg                 0
# fga                0
# fg_perc        22819
# 3p                 0
# 3pa                0
# 3p_perc       157057
# ft                 0
# fta                0
# ft_perc       189479
# orb                0
# drb                0
# trb                0
# ast                0
# stl                0
# blk                0
# tov                0
# pf                 0
# pts                0
# plus_minus        80
# season        532543
# dtype: int64

# %% [markdown]
# Clean data

# %%
df['fg_perc'] = df['fg'] / df['fga']
df['3p_perc'] = df['3p'] / df['3pa']
df['ft_perc'] = df['ft'] / df['fta']
df['min'] = df['mp'].apply(lambda x: int(x.split(':')[0]))
df['sec'] = df['mp'].apply(lambda x: int(x.split(':')[-1]))
df['pt'] = df['min'] + df['sec'] / 60
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['player'] = df['player'].apply(lambda x: unidecode(x.strip().lower()))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 539268 entries, 0 to 539883
# Data columns (total 32 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        539268 non-null  datetime64[ns]
#  1   visitor     539268 non-null  object
#  2   home        539268 non-null  object
#  3   team        539268 non-null  int64
#  4   starter     539268 non-null  float64
#  5   player      539268 non-null  object
#  6   mp          539268 non-null  object
#  7   fg          539268 non-null  float64
#  8   fga         539268 non-null  float64
#  9   fg_perc     425652 non-null  float64
#  10  3p          539268 non-null  float64
#  11  3pa         539268 non-null  float64
#  12  3p_perc     291414 non-null  float64
#  13  ft          539268 non-null  float64
#  14  fta         539268 non-null  float64
#  15  ft_perc     258992 non-null  float64
#  16  orb         539268 non-null  float64
#  17  drb         539268 non-null  float64
#  18  trb         539268 non-null  float64
#  19  ast         539268 non-null  float64
#  20  stl         539268 non-null  float64
#  21  blk         539268 non-null  float64
#  22  tov         539268 non-null  float64
#  23  pf          539268 non-null  float64
#  24  pts         539268 non-null  float64
#  25  plus_minus  539188 non-null  float64
#  26  season      6725 non-null    float64
#  27  min         539268 non-null  int64
#  28  sec         539268 non-null  int64
#  29  pt          539268 non-null  float64
#  30  year        539268 non-null  int64
#  31  month       539268 non-null  int64
# dtypes: datetime64[ns](1), float64(22), int64(5), object(4)
# memory usage: 135.8+ MB

# %% [markdown]
# Feature Engineer

# %%
x = df.groupby(['date', 'visitor', 'home', 'team'])[['fga', 'orb', 'tov', 'fta']].transform('sum')
df['possessions'] = x.fga - x.orb + x.tov + 0.4 * x.fta

# %%
def get_season(month, year):
    if 10 <= month <= 12:
        return year
    else:
        return year - 1

# %%
df['season'] = df.apply(lambda x: get_season(x.month, x.year), 1)
df['opponent'] = np.where(df['team'], df['visitor'], df['home'])

# %% [markdown]
# Merge Schedule

# %%
schedules = pd.read_csv("backend/data/schedules/2022.csv")
schedules['date'] = pd.to_datetime(schedules['date'])

home_schedule = schedules.copy()
home_schedule['team'] = 1
home_schedule['opponent'] = home_schedule['visitor']

visitor_schedule = schedules.copy()
visitor_schedule['team'] = 0
visitor_schedule['opponent'] = visitor_schedule['home']

schedules = pd.concat([home_schedule, visitor_schedule])

df = pd.merge(schedules, df, left_on = ['date', 'visitor', 'home', 'team', 'opponent'], right_on = ['date', 'visitor', 'home', 'team', 'opponent'], how = 'left')

# %% [markdown]
# Teams Defense

# %%
df.columns
# Out:
# Index(['date', 'visitor', 'home', 'season_x', 'team', 'opponent', 'starter',
#        'player', 'mp', 'fg', 'fga', 'fg_perc', '3p', '3pa', '3p_perc', 'ft',
#        'fta', 'ft_perc', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'plus_minus', 'season_y', 'min', 'sec', 'pt', 'year', 'month',
#        'possessions'],
#       dtype='object')

# %%
df['defense'] = np.where(df['team'], df['visitor'], df['home'])
defense_df = df.groupby(['date', 'defense'])[['3p']].sum().reset_index()

# %% [markdown]
# Feature engineer for defense

# %%
defense_df['date'] = pd.to_datetime(defense_df['date'])
defense_df['year'] = defense_df['date'].dt.year
defense_df['month'] = defense_df['date'].dt.month
defense_df['season'] = defense_df.apply(lambda x: get_season(x.month, x.year), 1)

# %% [markdown]
# Cumulative moving average for teams

# %%
defense_df['3pt'] = defense_df.groupby(['season', 'defense'])['3p'].shift(1)
defense_df['3pt_sum'] = defense_df.groupby(['season', 'defense'])['3pt'].expanding(min_periods=5).sum().sort_index(axis = 0, level = 2).values
defense_df['3pt_count'] = defense_df.groupby(['season', 'defense'])['3pt'].expanding(min_periods=5).count().sort_index(axis = 0, level = 2).values
defense_df['3pt_mean'] = defense_df.groupby(['season', 'defense'])['3pt'].expanding(min_periods=5).mean().sort_index(axis = 0, level = 2).values

# %% [markdown]
# League average

# %%
lg_sum = defense_df.groupby(['season', 'date'])['3pt'].sum().groupby(['season']).shift(1)
lg_sum = lg_sum.groupby(['season']).expanding(min_periods=5).sum()
lg_count = defense_df.groupby(['season', 'date'])['3pt'].count().groupby(['season']).shift(1)
lg_count = lg_count.groupby(['season']).expanding(min_periods=5).sum()
lg_avg = lg_sum / lg_count
lg_avg.index = defense_df.groupby(['season', 'date'])['3pt'].sum().index
lg_avg = lg_avg.reset_index()
defense_df = pd.merge(defense_df, lg_avg, on = ['season', 'date'], how = 'left', suffixes = ('', '_lg_avg'))

# %% [markdown]
# Merge in opposing defense

# %%
df = pd.merge(
    df, 
    defense_df[['defense', 'date', '3pt_mean', '3pt_lg_avg']], 
    left_on = ['opponent', 'date'], 
    right_on = ['defense', 'date'], 
    how = 'left', 
    suffixes = ('', '_opp')
)

# %% [markdown]
# Player Analysis

# %%
def player_analysis(player, date, df=df):
    # Normalize player name
    player = unidecode(player.strip().lower())

    # Edge cases where there a difference in player names
    edge_cases = {
        'bojan bogdanovich': 'bojan bogdanovic', 'caldwell pope kentavious': 'kentavious caldwell-pope',
        'pj tucker': 'p.j. tucker', 'robert williams iii': 'robert williams',
        'wendell carter': 'wendell carter jr.', 'christian james mccollum': 'cj mccollum',
        'grant jerami': 'jerami grant', 'huerter kevin': 'kevin huerter', 'p. j. tucker': 'p.j. tucker',
        'p.j tucker': 'p.j. tucker', 'nicolas claxton': 'nic claxton', 'cam johnson': 'cameron johnson',
        'rj barrett jr.': 'rj barrett', 'jimmy butler iii': 'jimmy butler', 'dorian finney smith': 'dorian finney-smith',
        'mike conley jr.': 'mike conley', 'anderson kyle': 'kyle anderson', 'jabari smith': 'jabari smith jr.', 
        'kj martin': 'kenyon martin jr.', 'jabari smith jr': 'jabari smith jr.', 'martin jr. k.': 'kenyon martin jr.',
        'alfred joel horford reynoso': 'al horford', 'j. tate': "jae'sean tate", 'anthony davis jr.': 'anthony davis',
        'murray dejounte': 'dejounte murray', 'brook robert lopez': 'brook lopez', 'og anunoby jr.': 'og anunoby',
        'marcus morris sr.': 'marcus morris', 'morris marcus': 'marcus morris', 'kelly oubre jr': 'kelly oubre jr.',
        'kelly oubre': 'kelly oubre jr.', 'dennis smith jr': 'dennis smith jr.', 'trendon watford (por)': 'trendon watford',
        'cameron thomas': 'cam thomas', 'durant kevin': 'kevin durant', 'xavier tillman': 'xavier tillman sr.',
        'k. caldwell-pope': 'kentavious caldwell-pope', 'michael porter': 'michael porter jr.', 'trey murphy': 'trey murphy iii',
        'troy brown jr': 'troy brown jr.', 'troy brown': 'troy brown jr.', 'marvin bagley': 'marvin bagley iii',
        'livers isaiah': 'isaiah livers', 'k. middleton': 'khris middleton', 'portis, bobby': 'bobby portis', 'bobby portis jr.': 'bobby portis',
        'pj washington': 'p.j. washington', 'p.j washington': 'p.j. washington', 'jabari smith ii': 'jabari smith jr.', 
        'kevin porter jr': 'kevin porter jr.', 'kevin porter': 'kevin porter jr.', 's. gilgeous-alexander': 'shai gilgeous-alexander', 
        'v. oladipo': 'victor oladipo', 'tim hardaway': 'tim hardaway jr.', 'westbrook russell': 'russell westbrook', 
        'p.j. washington jr.': 'p.j. washington', 'g. antetokounmpo': 'giannis antetokounmpo', 'lyles trey': 'trey lyles',
        'o.g. anunoby': 'og anunoby', 'r. mcgruder': 'rodney mcgruder', 'gary trent': 'gary trent jr.'
    }
    player = edge_cases.get(player, player)
    print(player)
    
    player_df = df.loc[(df['player'] == player) & (df['date'] <= date)].sort_values(by=['date'], ascending=True).copy()

    # Keep relevant team data (addresses trades)
    player_df.loc[:, 'team'] = np.where(player_df['team'] == 1, player_df['home'], player_df['visitor'])
    most_recent_team = player_df.loc[player_df['date'] == player_df['date'].max(), 'team'].values[0]
    player_df = player_df.loc[player_df['team'] == most_recent_team, :]

    # Keep games where player played
    player_df = player_df[player_df['pt'] != '0']

    # Add row to hole next game predictions
    player_df.loc['next_game', :] = None

    # Shift opposing defense and league average down a game
    player_df.loc[:, '3pt_mean'] = player_df.loc[:, '3pt_mean'].shift(1)
    player_df.loc[:, '3pt_lg_avg'] = player_df.loc[:, '3pt_lg_avg'].shift(1)

    # Cumulative moving average for threes
    player_df['3p'] = player_df['3p'].shift(1) 
    player_df['3p_sum'] = player_df['3p'].expanding(min_periods=5).sum().values
    player_df['3p_count'] = player_df['3p'].expanding(min_periods=5).count().values
    player_df['3p_mean'] = player_df['3p'].expanding(min_periods=5).mean().values

    return player_df

# %% [markdown]
# Normalize for opposing defense

# %%
def normalize(player_df):
    # Select next game
    mu_df = player_df.iloc[-1, :][['3p_mean', '3pt_mean', '3pt_lg_avg']]

    # # Normalize data
    normalize = 1 + (mu_df['3pt_mean'] - mu_df['3pt_lg_avg']) / mu_df['3pt_lg_avg']
    mu = mu_df['3p_mean'] * normalize

    return mu

# %% [markdown]
# Function to calculate implied odds

# %%
def convert_odds_to_perc(price):
    if price < 0:
        return abs(price) / (100 + abs(price))
    else:
        return 100 / (100 + price)

# %% [markdown]
# Function to calculate EV

# %%
def expected_value(prob, odds):
    return prob * odds - (1 - prob)

# %% [markdown]
# Calculate EV

# %%
def calculate_expected_value(projection, type, line, price):
    # Poisson distribution probability
    under = stats.poisson.cdf(k = line, mu = projection)
    over = 1 - under

    # Expected value
    if type == 'Over':
        ev = expected_value(over, convert_odds_to_perc(price))
    else:
        ev = expected_value(under, convert_odds_to_perc(price))
    
    return round(ev * 100, 1)

# %% [markdown]
# Load in player prop lines for date

# %%
next_game_date = date.today()

# %%
home_teams = schedules.loc[schedules['date'] == str(next_game_date), 'home'].to_list()
away_teams = schedules.loc[schedules['date'] == str(next_game_date), 'visitor'].to_list()

# %%
player_props = pd.read_csv("backend/data/odds/player_props/3pt.csv")
player_props['last_updated'] = pd.to_datetime(player_props.loc[:, 'last_updated'])
player_props = player_props.loc[
    (player_props['last_updated'].dt.date == next_game_date) & 
    (player_props['home'].isin(home_teams)) & 
    (player_props['away'].isin(away_teams))
]

# %% [markdown]
# Calculate EV and projection for each player and book

# %%
player_props['projection'] = player_props.apply(
    lambda row: normalize(player_analysis(row.player, str(next_game_date))),
    axis=1
)
player_props['EV'] = player_props.apply(
    lambda row: calculate_expected_value(row.projection, row.type, row.line, row.price),
    axis=1
)
# Out:
# caris levert
# caris levert
# darius garland
# darius garland
# dennis smith jr.
# dennis smith jr.
# evan mobley
# evan mobley
# gordon hayward
# gordon hayward
# isaac okoro
# isaac okoro
# kelly oubre jr.
# kelly oubre jr.
# lamar stevens
# lamar stevens
# p.j. washington
# p.j. washington
# ricky rubio
# ricky rubio
# terry rozier
# terry rozier
# darius garland
# darius garland
# kelly oubre jr.
# kelly oubre jr.
# isaac okoro
# isaac okoro
# gordon hayward
# gordon hayward
# terry rozier
# terry rozier
# p.j. washington
# p.j. washington
# caris levert
# caris levert
# evan mobley
# evan mobley
# kelly oubre jr.
# kelly oubre jr.
# dennis smith jr.
# dennis smith jr.
# caris levert
# caris levert
# lamar stevens
# lamar stevens
# isaac okoro
# isaac okoro
# ricky rubio
# ricky rubio
# lamar stevens
# lamar stevens
# isaac okoro
# isaac okoro
# dennis smith jr.
# dennis smith jr.
# darius garland
# darius garland
# ricky rubio
# ricky rubio
# p.j. washington
# p.j. washington
# gordon hayward
# gordon hayward
# evan mobley
# evan mobley
# kelly oubre jr.
# kelly oubre jr.
# caris levert
# caris levert
# terry rozier
# terry rozier
# darius garland
# darius garland
# evan mobley
# evan mobley
# gordon hayward
# gordon hayward
# p.j. washington
# p.j. washington
# terry rozier
# terry rozier
# kelly oubre jr.
# kelly oubre jr.
# isaac okoro
# isaac okoro
# dennis smith jr.
# dennis smith jr.
# lamar stevens
# lamar stevens
# caris levert
# caris levert
# gordon hayward
# gordon hayward
# terry rozier
# terry rozier
# kelly oubre jr.
# kelly oubre jr.
# p.j. washington
# p.j. washington
# darius garland
# darius garland
# isaac okoro
# isaac okoro
# caris levert
# caris levert
# caris levert
# caris levert
# gordon hayward
# gordon hayward
# isaac okoro
# isaac okoro
# kelly oubre jr.
# kelly oubre jr.
# p.j. washington
# p.j. washington
# terry rozier
# terry rozier
# gordon hayward
# gordon hayward
# p.j. washington
# p.j. washington
# terry rozier
# terry rozier
# kelly oubre jr.
# kelly oubre jr.
# darius garland
# darius garland
# gordon hayward
# gordon hayward
# p.j. washington
# p.j. washington
# terry rozier
# terry rozier
# kelly oubre jr.
# kelly oubre jr.
# darius garland
# darius garland
# bradley beal
# bradley beal
# eugene omoruyi
# eugene omoruyi
# james wiseman
# james wiseman
# killian hayes
# killian hayes
# kristaps porzingis
# kristaps porzingis
# monte morris
# monte morris
# rodney mcgruder
# rodney mcgruder
# rodney mcgruder
# rodney mcgruder
# monte morris
# monte morris
# bradley beal
# bradley beal
# kristaps porzingis
# kristaps porzingis
# killian hayes
# killian hayes
# kristaps porzingis
# kristaps porzingis
# monte morris
# monte morris
# killian hayes
# killian hayes
# james wiseman
# james wiseman
# rodney mcgruder
# rodney mcgruder
# eugene omoruyi
# eugene omoruyi
# monte morris
# monte morris
# bradley beal
# bradley beal
# rodney mcgruder
# rodney mcgruder
# eugene omoruyi
# eugene omoruyi
# james wiseman
# james wiseman
# kristaps porzingis
# kristaps porzingis
# killian hayes
# killian hayes
# kristaps porzingis
# kristaps porzingis
# bradley beal
# bradley beal
# monte morris
# monte morris
# killian hayes
# killian hayes
# james wiseman
# james wiseman
# rodney mcgruder
# rodney mcgruder
# eugene omoruyi
# eugene omoruyi
# bradley beal
# bradley beal
# kristaps porzingis
# kristaps porzingis
# killian hayes
# killian hayes
# bradley beal
# bradley beal
# kristaps porzingis
# kristaps porzingis
# killian hayes
# killian hayes
# bradley beal
# bradley beal
# kristaps porzingis
# kristaps porzingis
# killian hayes
# killian hayes
# rodney mcgruder
# rodney mcgruder
# bradley beal
# bradley beal
# killian hayes
# killian hayes
# kristaps porzingis
# kristaps porzingis
# monte morris
# monte morris
# aaron gordon
# aaron gordon
# fred vanvleet
# fred vanvleet
# gary trent jr.
# gary trent jr.
# kentavious caldwell-pope
# kentavious caldwell-pope
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# og anunoby
# og anunoby
# pascal siakam
# pascal siakam
# scottie barnes
# scottie barnes
# gary trent jr.
# gary trent jr.
# fred vanvleet
# fred vanvleet
# kentavious caldwell-pope
# kentavious caldwell-pope
# pascal siakam
# pascal siakam
# og anunoby
# og anunoby
# michael porter jr.
# michael porter jr.
# aaron gordon
# aaron gordon
# kentavious caldwell-pope
# kentavious caldwell-pope
# scottie barnes
# scottie barnes
# gary trent jr.
# gary trent jr.
# michael porter jr.
# michael porter jr.
# fred vanvleet
# fred vanvleet
# kentavious caldwell-pope
# kentavious caldwell-pope
# nikola jokic
# nikola jokic
# scottie barnes
# scottie barnes
# gary trent jr.
# gary trent jr.
# aaron gordon
# aaron gordon
# pascal siakam
# pascal siakam
# og anunoby
# og anunoby
# aaron gordon
# aaron gordon
# fred vanvleet
# fred vanvleet
# kentavious caldwell-pope
# kentavious caldwell-pope
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# og anunoby
# og anunoby
# pascal siakam
# pascal siakam
# scottie barnes
# scottie barnes
# gary trent jr.
# gary trent jr.
# pascal siakam
# pascal siakam
# og anunoby
# og anunoby
# kentavious caldwell-pope
# kentavious caldwell-pope
# michael porter jr.
# michael porter jr.
# gary trent jr.
# gary trent jr.
# kentavious caldwell-pope
# kentavious caldwell-pope
# fred vanvleet
# fred vanvleet
# gary trent jr.
# gary trent jr.
# michael porter jr.
# michael porter jr.
# og anunoby
# og anunoby
# pascal siakam
# pascal siakam
# pascal siakam
# pascal siakam
# fred vanvleet
# fred vanvleet
# og anunoby
# og anunoby
# kentavious caldwell-pope
# kentavious caldwell-pope
# michael porter jr.
# michael porter jr.
# gary trent jr.
# gary trent jr.
# pascal siakam
# pascal siakam
# fred vanvleet
# fred vanvleet
# og anunoby
# og anunoby
# kentavious caldwell-pope
# kentavious caldwell-pope
# michael porter jr.
# michael porter jr.
# gary trent jr.
# gary trent jr.
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# jalen williams
# jalen williams
# jaylin williams
# jaylin williams
# josh giddey
# josh giddey
# luguentz dort
# luguentz dort
# mikal bridges
# mikal bridges
# royce o'neale
# royce o'neale
# shai gilgeous-alexander
# shai gilgeous-alexander
# spencer dinwiddie
# spencer dinwiddie
# luguentz dort
# luguentz dort
# royce o'neale
# royce o'neale
# jalen williams
# jalen williams
# dorian finney-smith
# dorian finney-smith
# spencer dinwiddie
# spencer dinwiddie
# mikal bridges
# mikal bridges
# cameron johnson
# cameron johnson
# jalen williams
# jalen williams
# mikal bridges
# mikal bridges
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# josh giddey
# josh giddey
# jaylin williams
# jaylin williams
# mikal bridges
# mikal bridges
# cameron johnson
# cameron johnson
# spencer dinwiddie
# spencer dinwiddie
# dorian finney-smith
# dorian finney-smith
# luguentz dort
# luguentz dort
# jalen williams
# jalen williams
# mikal bridges
# mikal bridges
# cameron johnson
# cameron johnson
# spencer dinwiddie
# spencer dinwiddie
# dorian finney-smith
# dorian finney-smith
# luguentz dort
# luguentz dort
# jalen williams
# jalen williams
# josh giddey
# josh giddey
# mikal bridges
# mikal bridges
# shai gilgeous-alexander
# shai gilgeous-alexander
# spencer dinwiddie
# spencer dinwiddie
# royce o'neale
# royce o'neale
# jaylin williams
# jaylin williams
# jalen williams
# jalen williams
# cameron johnson
# cameron johnson
# luguentz dort
# luguentz dort
# dorian finney-smith
# dorian finney-smith
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# jalen williams
# jalen williams
# luguentz dort
# luguentz dort
# mikal bridges
# mikal bridges
# royce o'neale
# royce o'neale
# spencer dinwiddie
# spencer dinwiddie
# luguentz dort
# luguentz dort
# jalen williams
# jalen williams
# spencer dinwiddie
# spencer dinwiddie
# dorian finney-smith
# dorian finney-smith
# mikal bridges
# mikal bridges
# cameron johnson
# cameron johnson
# royce o'neale
# royce o'neale
# devin vassell
# devin vassell
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# zach collins
# zach collins
# wendell carter jr.
# wendell carter jr.
# gary harris
# gary harris
# paolo banchero
# paolo banchero
# devin vassell
# devin vassell
# gary harris
# gary harris
# wendell carter jr.
# wendell carter jr.
# paolo banchero
# paolo banchero
# devin vassell
# devin vassell
# zach collins
# zach collins
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# devin vassell
# devin vassell
# zach collins
# zach collins
# zach collins
# zach collins
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# devin vassell
# devin vassell
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# gary harris
# gary harris
# devin vassell
# devin vassell
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# gary harris
# gary harris
# devin vassell
# devin vassell
# gary harris
# gary harris
# wendell carter jr.
# wendell carter jr.
# paolo banchero
# paolo banchero
# devin vassell
# devin vassell
# devin vassell
# devin vassell
# gary harris
# gary harris
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# cj mccollum
# cj mccollum
# troy brown jr.
# troy brown jr.
# d'angelo russell
# d'angelo russell
# austin reaves
# austin reaves
# malik beasley
# malik beasley
# trey murphy iii
# trey murphy iii
# d'angelo russell
# d'angelo russell
# cj mccollum
# cj mccollum
# malik beasley
# malik beasley
# jarred vanderbilt
# jarred vanderbilt
# trey murphy iii
# trey murphy iii
# herbert jones
# herbert jones
# rui hachimura
# rui hachimura
# jonas valanciunas
# jonas valanciunas
# austin reaves
# austin reaves
# troy brown jr.
# troy brown jr.
# anthony davis
# anthony davis
# austin reaves
# austin reaves
# cj mccollum
# cj mccollum
# d'angelo russell
# d'angelo russell
# dennis schroder
# dennis schroder
# herbert jones
# herbert jones
# jarred vanderbilt
# jarred vanderbilt
# jonas valanciunas
# jonas valanciunas
# malik beasley
# malik beasley
# rui hachimura
# rui hachimura
# trey murphy iii
# trey murphy iii
# troy brown jr.
# troy brown jr.
# d'angelo russell
# d'angelo russell
# malik beasley
# malik beasley
# cj mccollum
# cj mccollum
# trey murphy iii
# trey murphy iii
# d'angelo russell
# d'angelo russell
# malik beasley
# malik beasley
# cj mccollum
# cj mccollum
# trey murphy iii
# trey murphy iii
# jonas valanciunas
# jonas valanciunas
# dennis schroder
# dennis schroder
# anthony davis
# anthony davis
# cj mccollum
# cj mccollum
# troy brown jr.
# troy brown jr.
# austin reaves
# austin reaves
# herbert jones
# herbert jones
# trey murphy iii
# trey murphy iii
# d'angelo russell
# d'angelo russell
# malik beasley
# malik beasley
# jarred vanderbilt
# jarred vanderbilt
# rui hachimura
# rui hachimura
# cj mccollum
# cj mccollum
# d'angelo russell
# d'angelo russell
# malik beasley
# malik beasley
# trey murphy iii
# trey murphy iii
# troy brown jr.
# troy brown jr.
# austin reaves
# austin reaves
# anthony davis
# anthony davis
# cj mccollum
# cj mccollum
# d'angelo russell
# d'angelo russell
# jarred vanderbilt
# jarred vanderbilt
# malik beasley
# malik beasley
# trey murphy iii
# trey murphy iii
# rui hachimura
# rui hachimura
# jonas valanciunas
# jonas valanciunas
# dennis schroder
# dennis schroder
# austin reaves
# austin reaves
# troy brown jr.
# troy brown jr.
# austin reaves
# austin reaves
# cj mccollum
# cj mccollum
# trey murphy iii
# trey murphy iii
# troy brown jr.
# troy brown jr.
# immanuel quickley
# immanuel quickley
# josh hart
# josh hart
# julius randle
# julius randle
# rj barrett
# rj barrett
# quentin grimes
# quentin grimes
# immanuel quickley
# immanuel quickley
# quentin grimes
# quentin grimes
# immanuel quickley
# immanuel quickley
# josh hart
# josh hart
# quentin grimes
# quentin grimes
# rj barrett
# rj barrett
# julius randle
# julius randle
# quentin grimes
# quentin grimes
# rj barrett
# rj barrett
# julius randle
# julius randle
# quentin grimes
# quentin grimes
# immanuel quickley
# immanuel quickley
# julius randle
# julius randle
# josh hart
# josh hart
# rj barrett
# rj barrett
# julius randle
# julius randle
# rj barrett
# rj barrett
# quentin grimes
# quentin grimes
# immanuel quickley
# immanuel quickley
# julius randle
# julius randle
# rj barrett
# rj barrett
# quentin grimes
# quentin grimes
# immanuel quickley
# immanuel quickley
# josh hart
# josh hart
# immanuel quickley
# immanuel quickley
# julius randle
# julius randle
# quentin grimes
# quentin grimes
# rj barrett
# rj barrett
# devin booker
# devin booker
# chris paul
# chris paul
# devin booker
# devin booker
# chris paul
# chris paul
# devin booker
# devin booker
# chris paul
# chris paul
# chris paul
# chris paul
# deandre ayton
# deandre ayton
# devin booker
# devin booker
# giannis antetokounmpo
# giannis antetokounmpo
# josh okogie
# josh okogie
# torrey craig
# torrey craig
# chris paul
# chris paul
# devin booker
# devin booker
# devin booker
# devin booker
# chris paul
# chris paul
# deandre ayton
# deandre ayton
# torrey craig
# torrey craig
# josh okogie
# josh okogie
# chris paul
# chris paul
# torrey craig
# torrey craig
# josh okogie
# josh okogie
# jrue holiday
# jrue holiday
# chris paul
# chris paul
# devin booker
# devin booker
# brook lopez
# brook lopez
# jrue holiday
# jrue holiday
# giannis antetokounmpo
# giannis antetokounmpo
# deandre ayton
# deandre ayton
# chris paul
# chris paul
# josh okogie
# josh okogie
# devin booker
# devin booker
# torrey craig
# torrey craig

# %% [markdown]
# Players with +EV

# %%
pd.set_option('display.max_rows', None)
player_props.loc[player_props['EV'] >= 10, :].sort_values(by=['date', 'home', 'player', 'book']).loc[:, ['home', 'away', 'player', 'type', 'line', 'price', 'projection', 'EV']]
# Out:
# 29
#                        home                 away             player   type  \
# 41        Charlotte Hornets  Cleveland Cavaliers    Dennis Smith Jr  Under
# 55        Charlotte Hornets  Cleveland Cavaliers   Dennis Smith Jr.  Under
# 37        Charlotte Hornets  Cleveland Cavaliers        Evan Mobley  Under
# 74        Charlotte Hornets  Cleveland Cavaliers        Evan Mobley  Under
# 7         Charlotte Hornets  Cleveland Cavaliers        Evan Mobley  Under
# 65        Charlotte Hornets  Cleveland Cavaliers        Evan Mobley  Under
# 129       Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 76        Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 109       Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 9         Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 29        Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 93        Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 119       Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 63        Charlotte Hornets  Cleveland Cavaliers     Gordon Hayward  Under
# 47        Charlotte Hornets  Cleveland Cavaliers        Isaac Okoro  Under
# 84        Charlotte Hornets  Cleveland Cavaliers        Isaac Okoro  Under
# 111       Charlotte Hornets  Cleveland Cavaliers        Isaac Okoro  Under
# 11        Charlotte Hornets  Cleveland Cavaliers        Isaac Okoro  Under
# 27        Charlotte Hornets  Cleveland Cavaliers        Isaac Okoro  Under
# 103       Charlotte Hornets  Cleveland Cavaliers        Isaac Okoro  Under
# 53        Charlotte Hornets  Cleveland Cavaliers        Isaac Okoro  Under
# 131       Charlotte Hornets  Cleveland Cavaliers    P.J. Washington  Under
# 121       Charlotte Hornets  Cleveland Cavaliers    P.J. Washington  Under
# 49        Charlotte Hornets  Cleveland Cavaliers        Ricky Rubio  Under
# 19        Charlotte Hornets  Cleveland Cavaliers        Ricky Rubio  Under
# 59        Charlotte Hornets  Cleveland Cavaliers        Ricky Rubio  Under
# 169      Washington Wizards      Detroit Pistons      James Wiseman  Under
# 197      Washington Wizards      Detroit Pistons      James Wiseman  Under
# 143      Washington Wizards      Detroit Pistons      James Wiseman  Under
# 183      Washington Wizards      Detroit Pistons      James Wiseman  Under
# 213      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 167      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 194      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 225      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 145      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 161      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 219      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 207      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 187      Washington Wizards      Detroit Pistons      Killian Hayes  Under
# 171      Washington Wizards      Detroit Pistons        R. McGruder  Under
# 198      Washington Wizards      Detroit Pistons    Rodney McGruder  Under
# 151      Washington Wizards      Detroit Pistons    Rodney McGruder  Under
# 153      Washington Wizards      Detroit Pistons    Rodney McGruder  Under
# 179      Washington Wizards      Detroit Pistons    Rodney McGruder  Under
# 221      Washington Wizards      Detroit Pistons    Rodney Mcgruder  Under
# 343         Toronto Raptors       Denver Nuggets       O.G. Anunoby  Under
# 331         Toronto Raptors       Denver Nuggets       O.G. Anunoby  Under
# 296         Toronto Raptors       Denver Nuggets         OG Anunoby  Under
# 243         Toronto Raptors       Denver Nuggets         OG Anunoby  Under
# 257         Toronto Raptors       Denver Nuggets         OG Anunoby  Under
# 285         Toronto Raptors       Denver Nuggets         OG Anunoby  Under
# 323         Toronto Raptors       Denver Nuggets     OG Anunoby Jr.  Under
# 307         Toronto Raptors       Denver Nuggets         Og Anunoby  Under
# 407   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 385   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 445   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 355   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 375   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 457   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 419   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 433   Oklahoma City Thunder        Brooklyn Nets     Jalen Williams  Under
# 401   Oklahoma City Thunder        Brooklyn Nets  Spencer Dinwiddie  Under
# 453   Oklahoma City Thunder        Brooklyn Nets  Spencer Dinwiddie  Under
# 369   Oklahoma City Thunder        Brooklyn Nets  Spencer Dinwiddie  Under
# 379   Oklahoma City Thunder        Brooklyn Nets  Spencer Dinwiddie  Under
# 459   Oklahoma City Thunder        Brooklyn Nets  Spencer Dinwiddie  Under
# 413   Oklahoma City Thunder        Brooklyn Nets  Spencer Dinwiddie  Under
# 427   Oklahoma City Thunder        Brooklyn Nets  Spencer Dinwiddie  Under
# 527       San Antonio Spurs        Orlando Magic        Gary Harris  Under
# 549       San Antonio Spurs        Orlando Magic        Gary Harris  Under
# 483       San Antonio Spurs        Orlando Magic        Gary Harris  Under
# 535       San Antonio Spurs        Orlando Magic        Gary Harris  Under
# 497       San Antonio Spurs        Orlando Magic       Zach Collins  Under
# 508       San Antonio Spurs        Orlando Magic       Zach Collins  Under
# 479       San Antonio Spurs        Orlando Magic       Zach Collins  Under
# 511       San Antonio Spurs        Orlando Magic       Zach Collins  Under
# 587    New Orleans Pelicans   Los Angeles Lakers      Anthony Davis  Under
# 631    New Orleans Pelicans   Los Angeles Lakers      Anthony Davis  Under
# 663    New Orleans Pelicans   Los Angeles Lakers  Anthony Davis Jr.  Under
# 582    New Orleans Pelicans   Los Angeles Lakers      Austin Reaves   Over
# 681    New Orleans Pelicans   Los Angeles Lakers      Austin Reaves   Over
# 684    New Orleans Pelicans   Los Angeles Lakers      Austin Reaves   Over
# 588    New Orleans Pelicans   Los Angeles Lakers      Austin Reaves   Over
# 560    New Orleans Pelicans   Los Angeles Lakers      Austin Reaves   Over
# 636    New Orleans Pelicans   Los Angeles Lakers      Austin Reaves   Over
# 679    New Orleans Pelicans   Los Angeles Lakers    Dennis Schroder   Over
# 594    New Orleans Pelicans   Los Angeles Lakers    Dennis Schroder   Over
# 628    New Orleans Pelicans   Los Angeles Lakers    Dennis Schroder   Over
# 573    New Orleans Pelicans   Los Angeles Lakers  Jarred Vanderbilt  Under
# 668    New Orleans Pelicans   Los Angeles Lakers  Jarred Vanderbilt  Under
# 599    New Orleans Pelicans   Los Angeles Lakers  Jarred Vanderbilt  Under
# 647    New Orleans Pelicans   Los Angeles Lakers  Jarred Vanderbilt  Under
# 708  Portland Trail Blazers      New York Knicks          Josh Hart   Over
# 749  Portland Trail Blazers      New York Knicks          Josh Hart   Over
# 694  Portland Trail Blazers      New York Knicks          Josh Hart   Over
# 728  Portland Trail Blazers      New York Knicks          Josh Hart   Over
# 791            Phoenix Suns      Milwaukee Bucks      Deandre Ayton  Under
# 773            Phoenix Suns      Milwaukee Bucks      Deandre Ayton  Under
# 815            Phoenix Suns      Milwaukee Bucks      Deandre Ayton  Under
# 801            Phoenix Suns      Milwaukee Bucks        Josh Okogie  Under
# 794            Phoenix Suns      Milwaukee Bucks        Josh Okogie  Under
# 779            Phoenix Suns      Milwaukee Bucks        Josh Okogie  Under
# 819            Phoenix Suns      Milwaukee Bucks        Josh Okogie  Under
# 798            Phoenix Suns      Milwaukee Bucks       Torrey Craig   Over
# 793            Phoenix Suns      Milwaukee Bucks       Torrey Craig   Over
# 780            Phoenix Suns      Milwaukee Bucks       Torrey Craig   Over
# 822            Phoenix Suns      Milwaukee Bucks       Torrey Craig   Over
#
#      line  price  projection    EV
# 41    0.5   -160    0.382470  10.2
# 55    0.5   -160    0.382470  10.2
# 37    0.5   -225    0.293802  26.1
# 74    0.5   -233    0.293802  26.7
# 7     0.5   -220    0.293802  25.8
# 65    0.5   -234    0.293802  26.8
# 129   1.5   -205    0.992186  23.5
# 76    1.5   -222    0.992186  24.8
# 109   1.5   -215    0.992186  24.3
# 9     1.5   -205    0.992186  23.5
# 29    1.5   -215    0.992186  24.3
# 93    1.5   -200    0.992186  23.1
# 119   1.5   -205    0.992186  23.5
# 63    1.5   -244    0.992186  26.3
# 47    1.5   -210    0.810894  35.0
# 84    1.5   -208    0.810894  34.8
# 111   1.5   -215    0.810894  35.4
# 11    1.5   -205    0.810894  34.6
# 27    1.5   -215    0.810894  35.4
# 103   1.5   -225    0.810894  36.2
# 53    1.5   -199    0.810894  34.1
# 131   2.5   -200    1.843847  19.8
# 121   2.5   -200    1.843847  19.8
# 49    1.5   -200    0.829323  33.0
# 19    1.5   -190    0.829323  32.1
# 59    1.5   -194    0.829323  32.5
# 169   0.5   -450    0.182935  51.4
# 197   0.5   -417    0.182935  50.5
# 143   0.5   -400    0.182935  49.9
# 183   0.5   -429    0.182935  50.8
# 213   1.5   -167    0.991560  20.1
# 167   1.5   -165    0.991560  19.9
# 194   1.5   -164    0.991560  19.8
# 225   1.5   -165    0.991560  19.9
# 145   1.5   -160    0.991560  19.4
# 161   1.5   -162    0.991560  19.6
# 219   1.5   -160    0.991560  19.4
# 207   1.5   -167    0.991560  20.1
# 187   1.5   -169    0.991560  20.3
# 171   2.5   -150    0.414293  58.6
# 198   2.5   -149    0.414293  58.4
# 151   2.5   -145    0.414293  57.8
# 153   2.5   -154    0.414293  59.2
# 179   2.5   -157    0.414293  59.7
# 221   2.5   -145    0.414293  57.8
# 343   2.5   -159    1.967636  10.6
# 331   2.5   -159    1.967636  10.6
# 296   2.5   -172    1.967636  11.9
# 243   2.5   -175    1.967636  12.2
# 257   2.5   -172    1.967636  11.9
# 285   2.5   -179    1.967636  12.5
# 323   2.5   -170    1.967636  11.7
# 307   2.5   -175    1.967636  12.2
# 407   1.5   -177    0.956882  23.2
# 385   1.5   -210    0.956882  26.1
# 445   1.5   -180    0.956882  23.5
# 355   1.5   -205    0.956882  25.7
# 375   1.5   -180    0.956882  23.5
# 457   1.5   -180    0.956882  23.5
# 419   1.5   -177    0.956882  23.2
# 433   1.5   -214    0.956882  26.4
# 401   2.5   -122    1.788287  13.7
# 453   2.5   -130    1.788287  14.8
# 369   2.5   -140    1.788287  16.2
# 379   2.5   -130    1.788287  14.8
# 459   2.5   -130    1.788287  14.8
# 413   2.5   -122    1.788287  13.7
# 427   2.5   -145    1.788287  16.8
# 527   2.5   -200    1.934907  15.7
# 549   2.5   -215    1.934907  16.8
# 483   2.5   -210    1.934907  16.5
# 535   2.5   -200    1.934907  15.7
# 497   1.5   -250    0.773142  40.3
# 508   1.5   -238    0.773142  39.5
# 479   1.5   -220    0.773142  38.1
# 511   1.5   -234    0.773142  39.2
# 587   0.5   -195    0.403451  11.0
# 631   0.5   -204    0.403451  11.6
# 663   0.5   -200    0.403451  11.3
# 582   0.5   -250    1.289926  24.2
# 681   0.5   -238    1.289926  23.5
# 684   0.5   -250    1.289926  24.2
# 588   0.5   -220    1.289926  22.3
# 560   0.5   -250    1.289926  24.2
# 636   0.5   -214    1.289926  21.9
# 679   0.5   -192    1.237601  17.7
# 594   0.5   -180    1.237601  16.6
# 628   0.5   -184    1.237601  17.0
# 573   0.5   -250    0.348075  21.0
# 668   0.5   -250    0.348075  21.0
# 599   0.5   -240    0.348075  20.4
# 647   0.5   -244    0.348075  20.7
# 708   0.5   -175    1.342871  20.9
# 749   0.5   -175    1.342871  20.9
# 694   0.5   -165    1.342871  19.9
# 728   0.5   -174    1.342871  20.8
# 791   0.5  -2500    0.115928  74.7
# 773   0.5  -2100    0.115928  74.1
# 815   0.5  -2504    0.115928  74.7
# 801   1.5   -135    0.819024  26.3
# 794   1.5   -133    0.819024  26.0
# 779   1.5   -130    0.819024  25.5
# 819   1.5   -133    0.819024  26.0
# 798   0.5   -190    1.320816  21.3
# 793   0.5   -192    1.320816  21.5
# 780   0.5   -180    1.320816  20.4
# 822   0.5   -194    1.320816  21.7
