# %% [markdown]
# # Rebounds

# %%
import os
import pandas as pd
import numpy as np
import scipy.stats as stats
from unidecode import unidecode
from datetime import date

# %%
os.chdir('/home/tylerengland/NBA')
os.getcwd()
# Out:
# '/home/tylerengland/NBA'

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('backend/data/details/game_details.csv')

# %%
df.head()
# Out:
#                 date        visitor        home  team  starter        player  \
# 0  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0  Kirk Hinrich
# 1  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0   Ben Wallace
# 2  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0     Luol Deng
# 3  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0    Ben Gordon
# 4  Tue, Oct 31, 2006  Chicago Bulls  Miami Heat     0      1.0    P.J. Brown
#
#          mp    fg   fga  fg_perc  ...  drb   trb  ast  stl  blk  tov   pf  \
# 0  34:38:00  10.0  18.0    0.556  ...  4.0   4.0  3.0  2.0  0.0  0.0  2.0
# 1  28:29:00   2.0   5.0    0.400  ...  5.0  11.0  1.0  0.0  1.0  0.0  2.0
# 2  24:07:00   4.0   9.0    0.444  ...  1.0   2.0  1.0  1.0  0.0  3.0  2.0
# 3     22:56   1.0   9.0    0.111  ...  1.0   1.0  2.0  1.0  0.0  2.0  3.0
# 4     18:23   1.0   2.0    0.500  ...  3.0   3.0  1.0  1.0  1.0  2.0  3.0
#
#     pts  plus_minus  season
# 0  26.0        23.0     NaN
# 1   5.0        13.0     NaN
# 2  12.0         8.0     NaN
# 3   6.0         7.0     NaN
# 4   4.0        15.0     NaN
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['date', 'visitor', 'home', 'team', 'starter', 'player', 'mp', 'fg',
#        'fga', 'fg_perc', '3p', '3pa', '3p_perc', 'ft', 'fta', 'ft_perc', 'orb',
#        'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'plus_minus',
#        'season'],
#       dtype='object')

# %% [markdown]
# Drop duplicates and NA's

# %%
df.drop_duplicates(subset=['date', 'visitor', 'home', 'team', 'player'], inplace=True)

# %%
df.dropna(subset = ['player'], inplace = True)

# %%
df.isna().sum()
# Out:
# date               0
# visitor            0
# home               0
# team               0
# starter            0
# player             0
# mp                 0
# fg                 0
# fga                0
# fg_perc        22819
# 3p                 0
# 3pa                0
# 3p_perc       157057
# ft                 0
# fta                0
# ft_perc       189479
# orb                0
# drb                0
# trb                0
# ast                0
# stl                0
# blk                0
# tov                0
# pf                 0
# pts                0
# plus_minus        80
# season        532543
# dtype: int64

# %% [markdown]
# Clean data

# %%
df['fg_perc'] = df['fg'] / df['fga']
df['3p_perc'] = df['3p'] / df['3pa']
df['ft_perc'] = df['ft'] / df['fta']
df['min'] = df['mp'].apply(lambda x: int(x.split(':')[0]))
df['sec'] = df['mp'].apply(lambda x: int(x.split(':')[-1]))
df['pt'] = df['min'] + df['sec'] / 60
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['player'] = df['player'].apply(lambda x: unidecode(x.strip().lower()))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 539268 entries, 0 to 539883
# Data columns (total 32 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        539268 non-null  datetime64[ns]
#  1   visitor     539268 non-null  object
#  2   home        539268 non-null  object
#  3   team        539268 non-null  int64
#  4   starter     539268 non-null  float64
#  5   player      539268 non-null  object
#  6   mp          539268 non-null  object
#  7   fg          539268 non-null  float64
#  8   fga         539268 non-null  float64
#  9   fg_perc     425652 non-null  float64
#  10  3p          539268 non-null  float64
#  11  3pa         539268 non-null  float64
#  12  3p_perc     291414 non-null  float64
#  13  ft          539268 non-null  float64
#  14  fta         539268 non-null  float64
#  15  ft_perc     258992 non-null  float64
#  16  orb         539268 non-null  float64
#  17  drb         539268 non-null  float64
#  18  trb         539268 non-null  float64
#  19  ast         539268 non-null  float64
#  20  stl         539268 non-null  float64
#  21  blk         539268 non-null  float64
#  22  tov         539268 non-null  float64
#  23  pf          539268 non-null  float64
#  24  pts         539268 non-null  float64
#  25  plus_minus  539188 non-null  float64
#  26  season      6725 non-null    float64
#  27  min         539268 non-null  int64
#  28  sec         539268 non-null  int64
#  29  pt          539268 non-null  float64
#  30  year        539268 non-null  int64
#  31  month       539268 non-null  int64
# dtypes: datetime64[ns](1), float64(22), int64(5), object(4)
# memory usage: 135.8+ MB

# %% [markdown]
# Feature Engineer

# %%
x = df.groupby(['date', 'visitor', 'home', 'team'])[['fga', 'orb', 'tov', 'fta']].transform('sum')
df['possessions'] = x.fga - x.orb + x.tov + 0.4 * x.fta

# %%
def get_season(month, year):
    if 10 <= month <= 12:
        return year
    else:
        return year - 1

# %%
df['season'] = df.apply(lambda x: get_season(x.month, x.year), 1)
df['opponent'] = np.where(df['team'], df['visitor'], df['home'])

# %% [markdown]
# Merge Schedule

# %%
schedules = pd.read_csv("backend/data/schedules/2022.csv")
schedules['date'] = pd.to_datetime(schedules['date'])

home_schedule = schedules.copy()
home_schedule['team'] = 1
home_schedule['opponent'] = home_schedule['visitor']

visitor_schedule = schedules.copy()
visitor_schedule['team'] = 0
visitor_schedule['opponent'] = visitor_schedule['home']

schedules = pd.concat([home_schedule, visitor_schedule])

df = pd.merge(schedules, df, left_on = ['date', 'visitor', 'home', 'team', 'opponent'], right_on = ['date', 'visitor', 'home', 'team', 'opponent'], how = 'left')

# %% [markdown]
# Teams Defense

# %%
df.columns
# Out:
# Index(['date', 'visitor', 'home', 'season_x', 'team', 'opponent', 'starter',
#        'player', 'mp', 'fg', 'fga', 'fg_perc', '3p', '3pa', '3p_perc', 'ft',
#        'fta', 'ft_perc', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'plus_minus', 'season_y', 'min', 'sec', 'pt', 'year', 'month',
#        'possessions'],
#       dtype='object')

# %%
df['defense'] = np.where(df['team'], df['visitor'], df['home'])
defense_df = df.groupby(['date', 'defense'])[['trb']].sum().reset_index()

# %%
df['defense'] = np.where(df['team'], df['visitor'], df['home'])
defense_df = df.groupby(['date', 'defense'])[['trb']].sum().reset_index()

# %% [markdown]
# Feature engineer for defense

# %%
defense_df['date'] = pd.to_datetime(defense_df['date'])
defense_df['year'] = defense_df['date'].dt.year
defense_df['month'] = defense_df['date'].dt.month
defense_df['season'] = defense_df.apply(lambda x: get_season(x.month, x.year), 1)

# %% [markdown]
# Cumulative moving average for teams

# %%
defense_df['rb'] = defense_df.groupby(['season', 'defense'])['trb'].shift(1)
defense_df['trb_sum'] = defense_df.groupby(['season', 'defense'])['rb'].expanding(min_periods=5).sum().sort_index(axis = 0, level = 2).values
defense_df['trb_count'] = defense_df.groupby(['season', 'defense'])['rb'].expanding(min_periods=5).count().sort_index(axis = 0, level = 2).values
defense_df['trb_mean'] = defense_df.groupby(['season', 'defense'])['rb'].expanding(min_periods=5).mean().sort_index(axis = 0, level = 2).values

# %% [markdown]
# League average

# %%
rb_lg_sum = defense_df.groupby(['season', 'date'])['trb'].sum().groupby(['season']).shift(1)
rb_lg_sum = rb_lg_sum.groupby(['season']).expanding(min_periods=5).sum()
rb_lg_count = defense_df.groupby(['season', 'date'])['trb'].count().groupby(['season']).shift(1)
rb_lg_count = rb_lg_count.groupby(['season']).expanding(min_periods=5).sum()
rb_lg_avg = rb_lg_sum / rb_lg_count
rb_lg_avg.index = defense_df.groupby(['season', 'date'])['trb'].sum().index
rb_lg_avg = rb_lg_avg.reset_index()
defense_df = pd.merge(defense_df, rb_lg_avg, on = ['season', 'date'], how = 'left', suffixes = ('', '_lg_avg'))

# %% [markdown]
# Merge in opposing defense

# %%
df = pd.merge(
    df, 
    defense_df[['defense', 'date', 'trb_mean', 'trb_lg_avg']], 
    left_on = ['opponent', 'date'], 
    right_on = ['defense', 'date'], 
    how = 'left', 
    suffixes = ('', '_opp')
)

# %% [markdown]
# Player Analysis

# %%
def player_analysis(player, date, df=df):
    # Normalize player name
    player = unidecode(player.strip().lower())

    # Edge cases where there a difference in player names
    edge_cases = {
        'bojan bogdanovich': 'bojan bogdanovic', 'caldwell pope kentavious': 'kentavious caldwell-pope',
        'pj tucker': 'p.j. tucker', 'robert williams iii': 'robert williams',
        'wendell carter': 'wendell carter jr.', 'christian james mccollum': 'cj mccollum',
        'grant jerami': 'jerami grant', 'huerter kevin': 'kevin huerter', 'p. j. tucker': 'p.j. tucker',
        'p.j tucker': 'p.j. tucker', 'nicolas claxton': 'nic claxton', 'cam johnson': 'cameron johnson',
        'rj barrett jr.': 'rj barrett', 'jimmy butler iii': 'jimmy butler', 'dorian finney smith': 'dorian finney-smith',
        'mike conley jr.': 'mike conley', 'anderson kyle': 'kyle anderson', 'jabari smith': 'jabari smith jr.', 
        'kj martin': 'kenyon martin jr.', 'jabari smith jr': 'jabari smith jr.', 'martin jr. k.': 'kenyon martin jr.',
        'alfred joel horford reynoso': 'al horford', 'j. tate': "jae'sean tate", 'anthony davis jr.': 'anthony davis',
        'murray dejounte': 'dejounte murray', 'brook robert lopez': 'brook lopez', 'og anunoby jr.': 'og anunoby',
        'marcus morris sr.': 'marcus morris', 'morris marcus': 'marcus morris', 'kelly oubre jr': 'kelly oubre jr.',
        'kelly oubre': 'kelly oubre jr.', 'dennis smith jr': 'dennis smith jr.', 'trendon watford (por)': 'trendon watford',
        'cameron thomas': 'cam thomas', 'durant kevin': 'kevin durant', 'xavier tillman': 'xavier tillman sr.',
        'k. caldwell-pope': 'kentavious caldwell-pope', 'michael porter': 'michael porter jr.', 'trey murphy': 'trey murphy iii',
        'troy brown jr': 'troy brown jr.', 'troy brown': 'troy brown jr.', 'marvin bagley': 'marvin bagley iii',
        'livers isaiah': 'isaiah livers', 'k. middleton': 'khris middleton', 'portis, bobby': 'bobby portis', 'bobby portis jr.': 'bobby portis',
        'pj washington': 'p.j. washington', 'p.j washington': 'p.j. washington', 'jabari smith ii': 'jabari smith jr.', 
        'kevin porter jr': 'kevin porter jr.', 'kevin porter': 'kevin porter jr.', 's. gilgeous-alexander': 'shai gilgeous-alexander', 
        'v. oladipo': 'victor oladipo', 'tim hardaway': 'tim hardaway jr.', 'westbrook russell': 'russell westbrook', 
        'p.j. washington jr.': 'p.j. washington', 'g. antetokounmpo': 'giannis antetokounmpo', 'lyles trey': 'trey lyles',
        'o.g. anunoby': 'og anunoby'
    }
    player = edge_cases.get(player, player)
    print(player)
    
    player_df = df.loc[(df['player'] == player) & (df['date'] <= date)].sort_values(by=['date'], ascending=True).copy()

    # Keep relevant team data (addresses trades)
    player_df.loc[:, 'team'] = np.where(player_df['team'] == 1, player_df['home'], player_df['visitor'])
    most_recent_team = player_df.loc[player_df['date'] == player_df['date'].max(), 'team'].values[0]
    player_df = player_df.loc[player_df['team'] == most_recent_team, :]

    # Keep games where player played
    player_df = player_df[player_df['pt'] != '0']

    # Add row to hole next game predictions
    player_df.loc['next_game', :] = None

    # Cumulative moving average for rebounds
    player_df['rb'] = player_df['trb'].shift(1) 
    player_df['rb_sum'] = player_df['rb'].expanding(min_periods=5).sum().values
    player_df['rb_count'] = player_df['rb'].expanding(min_periods=5).count().values
    player_df['rb_mean'] = player_df['rb'].expanding(min_periods=5).mean().values

    return player_df

# %% [markdown]
# Normalize for opposing defense

# %%
def normalize(player_df):
    # Select next game
    mu_df = player_df.iloc[-1, :][['rb_mean', 'trb_mean', 'trb_lg_avg']]

    # # Normalize data
    normalize = 1 + (mu_df['trb_mean'] - mu_df['trb_lg_avg']) / mu_df['trb_lg_avg']
    mu = mu_df['rb_mean'] * normalize

    return mu

# %% [markdown]
# Function to calculate implied odds

# %%
def convert_odds_to_perc(price):
    if price < 0:
        return abs(price) / (100 + abs(price))
    else:
        return 100 / (100 + price)

# %% [markdown]
# Function to calculate EV

# %%
def expected_value(prob, odds):
    return prob * odds - (1 - prob)

# %% [markdown]
# Calculate EV

# %%
def calculate_expected_value(projection, type, line, price):
    # Poisson distribution probability
    under = stats.poisson.cdf(k = line, mu = projection)
    over = 1 - under

    # Expected value
    if type == 'Over':
        ev = expected_value(over, convert_odds_to_perc(price))
    else:
        ev = expected_value(under, convert_odds_to_perc(price))
    
    return round(ev * 100, 1)

# %% [markdown]
# Load in player prop lines for date

# %%
next_game_date = date.today()

# %%
home_teams = schedules.loc[schedules['date'] == str(next_game_date), 'home'].to_list()
away_teams = schedules.loc[schedules['date'] == str(next_game_date), 'visitor'].to_list()

# %%
player_props = pd.read_csv("backend/data/odds/player_props/rebounds.csv")
player_props['last_updated'] = pd.to_datetime(player_props.loc[:, 'last_updated'])
player_props = player_props.loc[
    (player_props['last_updated'].dt.date == next_game_date) & 
    (player_props['home'].isin(home_teams)) & 
    (player_props['away'].isin(away_teams))
]

# %% [markdown]
# Calculate EV and projection for each player and book

# %%
player_props['projection'] = player_props.apply(
    lambda row: normalize(player_analysis(row.player, str(next_game_date))),
    axis=1
)
player_props['EV'] = player_props.apply(
    lambda row: calculate_expected_value(row.projection, row.type, row.line, row.price),
    axis=1
)
# Out:
# darius garland
# darius garland
# dennis smith jr.
# dennis smith jr.
# donovan mitchell
# donovan mitchell
# evan mobley
# evan mobley
# gordon hayward
# gordon hayward
# isaac okoro
# isaac okoro
# kelly oubre jr.
# kelly oubre jr.
# scottie barnes
# scottie barnes
# gary trent jr.
# gary trent jr.
# og anunoby
# og anunoby
# fred vanvleet
# fred vanvleet
# aaron gordon
# aaron gordon
# scottie barnes
# scottie barnes
# kentavious caldwell-pope
# kentavious caldwell-pope
# jakob poeltl
# jakob poeltl
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# pascal siakam
# pascal siakam
# aaron gordon
# aaron gordon
# fred vanvleet
# fred vanvleet
# jakob poeltl
# jakob poeltl
# kentavious caldwell-pope
# kentavious caldwell-pope
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# og anunoby
# og anunoby
# pascal siakam
# pascal siakam
# scottie barnes
# scottie barnes
# gary trent jr.
# gary trent jr.
# aaron gordon
# aaron gordon
# fred vanvleet
# fred vanvleet
# jakob poeltl
# jakob poeltl
# kentavious caldwell-pope
# kentavious caldwell-pope
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# og anunoby
# og anunoby
# pascal siakam
# pascal siakam
# scottie barnes
# scottie barnes
# aaron gordon
# aaron gordon
# kentavious caldwell-pope
# kentavious caldwell-pope
# fred vanvleet
# fred vanvleet
# jakob poeltl
# jakob poeltl
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# og anunoby
# og anunoby
# pascal siakam
# pascal siakam
# scottie barnes
# scottie barnes
# jakob poeltl
# jakob poeltl
# og anunoby
# og anunoby
# scottie barnes
# scottie barnes
# pascal siakam
# pascal siakam
# fred vanvleet
# fred vanvleet
# kentavious caldwell-pope
# kentavious caldwell-pope
# aaron gordon
# aaron gordon
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# jakob poeltl
# jakob poeltl
# og anunoby
# og anunoby
# scottie barnes
# scottie barnes
# pascal siakam
# pascal siakam
# fred vanvleet
# fred vanvleet
# kentavious caldwell-pope
# kentavious caldwell-pope
# aaron gordon
# aaron gordon
# michael porter jr.
# michael porter jr.
# nikola jokic
# nikola jokic
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# jalen williams
# jalen williams
# josh giddey
# josh giddey
# luguentz dort
# luguentz dort
# mikal bridges
# mikal bridges
# nic claxton
# nic claxton
# royce o'neale
# royce o'neale
# shai gilgeous-alexander
# shai gilgeous-alexander
# spencer dinwiddie
# spencer dinwiddie
# josh giddey
# josh giddey
# nic claxton
# nic claxton
# shai gilgeous-alexander
# shai gilgeous-alexander
# spencer dinwiddie
# spencer dinwiddie
# dorian finney-smith
# dorian finney-smith
# mikal bridges
# mikal bridges
# cameron johnson
# cameron johnson
# luguentz dort
# luguentz dort
# jalen williams
# jalen williams
# nic claxton
# nic claxton
# spencer dinwiddie
# spencer dinwiddie
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# mikal bridges
# mikal bridges
# shai gilgeous-alexander
# shai gilgeous-alexander
# luguentz dort
# luguentz dort
# josh giddey
# josh giddey
# jalen williams
# jalen williams
# nic claxton
# nic claxton
# spencer dinwiddie
# spencer dinwiddie
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# mikal bridges
# mikal bridges
# shai gilgeous-alexander
# shai gilgeous-alexander
# luguentz dort
# luguentz dort
# josh giddey
# josh giddey
# jalen williams
# jalen williams
# luguentz dort
# luguentz dort
# josh giddey
# josh giddey
# dorian finney-smith
# dorian finney-smith
# cameron johnson
# cameron johnson
# royce o'neale
# royce o'neale
# mikal bridges
# mikal bridges
# jalen williams
# jalen williams
# nic claxton
# nic claxton
# spencer dinwiddie
# spencer dinwiddie
# shai gilgeous-alexander
# shai gilgeous-alexander
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# jalen williams
# jalen williams
# josh giddey
# josh giddey
# luguentz dort
# luguentz dort
# mikal bridges
# mikal bridges
# nic claxton
# nic claxton
# shai gilgeous-alexander
# shai gilgeous-alexander
# spencer dinwiddie
# spencer dinwiddie
# cameron johnson
# cameron johnson
# dorian finney-smith
# dorian finney-smith
# jalen williams
# jalen williams
# josh giddey
# josh giddey
# luguentz dort
# luguentz dort
# mikal bridges
# mikal bridges
# nic claxton
# nic claxton
# shai gilgeous-alexander
# shai gilgeous-alexander
# spencer dinwiddie
# spencer dinwiddie
# devin vassell
# devin vassell
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# zach collins
# zach collins
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# markelle fultz
# markelle fultz
# gary harris
# gary harris
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# wendell carter jr.
# wendell carter jr.
# paolo banchero
# paolo banchero
# devin vassell
# devin vassell
# zach collins
# zach collins
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# zach collins
# zach collins
# devin vassell
# devin vassell
# gary harris
# gary harris
# devin vassell
# devin vassell
# markelle fultz
# markelle fultz
# zach collins
# zach collins
# wendell carter jr.
# wendell carter jr.
# paolo banchero
# paolo banchero
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# gary harris
# gary harris
# wendell carter jr.
# wendell carter jr.
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# gary harris
# gary harris
# wendell carter jr.
# wendell carter jr.
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# gary harris
# gary harris
# markelle fultz
# markelle fultz
# paolo banchero
# paolo banchero
# wendell carter jr.
# wendell carter jr.
# cj mccollum
# cj mccollum
# anthony davis
# anthony davis
# d'angelo russell
# d'angelo russell
# jarred vanderbilt
# jarred vanderbilt
# malik beasley
# malik beasley
# anthony davis
# anthony davis
# d'angelo russell
# d'angelo russell
# cj mccollum
# cj mccollum
# malik beasley
# malik beasley
# jarred vanderbilt
# jarred vanderbilt
# herbert jones
# herbert jones
# trey murphy iii
# trey murphy iii
# rui hachimura
# rui hachimura
# jonas valanciunas
# jonas valanciunas
# anthony davis
# anthony davis
# cj mccollum
# cj mccollum
# d'angelo russell
# d'angelo russell
# herbert jones
# herbert jones
# jarred vanderbilt
# jarred vanderbilt
# jonas valanciunas
# jonas valanciunas
# malik beasley
# malik beasley
# rui hachimura
# rui hachimura
# trey murphy iii
# trey murphy iii
# anthony davis
# anthony davis
# d'angelo russell
# d'angelo russell
# jarred vanderbilt
# jarred vanderbilt
# malik beasley
# malik beasley
# cj mccollum
# cj mccollum
# anthony davis
# anthony davis
# d'angelo russell
# d'angelo russell
# jarred vanderbilt
# jarred vanderbilt
# malik beasley
# malik beasley
# cj mccollum
# cj mccollum
# cj mccollum
# cj mccollum
# rui hachimura
# rui hachimura
# malik beasley
# malik beasley
# d'angelo russell
# d'angelo russell
# jonas valanciunas
# jonas valanciunas
# trey murphy iii
# trey murphy iii
# jarred vanderbilt
# jarred vanderbilt
# herbert jones
# herbert jones
# anthony davis
# anthony davis
# cj mccollum
# cj mccollum
# d'angelo russell
# d'angelo russell
# jarred vanderbilt
# jarred vanderbilt
# malik beasley
# malik beasley
# anthony davis
# anthony davis
# cj mccollum
# cj mccollum
# d'angelo russell
# d'angelo russell
# jarred vanderbilt
# jarred vanderbilt
# malik beasley
# malik beasley
# herbert jones
# herbert jones
# trey murphy iii
# trey murphy iii
# rui hachimura
# rui hachimura
# jonas valanciunas
# jonas valanciunas
# anthony davis
# anthony davis
# cj mccollum
# cj mccollum
# immanuel quickley
# immanuel quickley
# julius randle
# julius randle
# mitchell robinson
# mitchell robinson
# quentin grimes
# quentin grimes
# rj barrett
# rj barrett
# quentin grimes
# quentin grimes
# julius randle
# julius randle
# mitchell robinson
# mitchell robinson
# rj barrett
# rj barrett
# quentin grimes
# quentin grimes
# mitchell robinson
# mitchell robinson
# julius randle
# julius randle
# rj barrett
# rj barrett
# immanuel quickley
# immanuel quickley
# rj barrett
# rj barrett
# mitchell robinson
# mitchell robinson
# quentin grimes
# quentin grimes
# julius randle
# julius randle
# rj barrett
# rj barrett
# mitchell robinson
# mitchell robinson
# quentin grimes
# quentin grimes
# julius randle
# julius randle
# quentin grimes
# quentin grimes
# julius randle
# julius randle
# rj barrett
# rj barrett
# immanuel quickley
# immanuel quickley
# mitchell robinson
# mitchell robinson
# julius randle
# julius randle
# mitchell robinson
# mitchell robinson
# quentin grimes
# quentin grimes
# rj barrett
# rj barrett
# julius randle
# julius randle
# rj barrett
# rj barrett
# mitchell robinson
# mitchell robinson
# quentin grimes
# quentin grimes
# immanuel quickley
# immanuel quickley
# julius randle
# julius randle
# mitchell robinson
# mitchell robinson
# quentin grimes
# quentin grimes
# rj barrett
# rj barrett
# chris paul
# chris paul
# devin booker
# devin booker
# deandre ayton
# deandre ayton
# devin booker
# devin booker
# chris paul
# chris paul
# deandre ayton
# deandre ayton
# devin booker
# devin booker
# chris paul
# chris paul
# deandre ayton
# deandre ayton
# chris paul
# chris paul
# deandre ayton
# deandre ayton
# devin booker
# devin booker
# chris paul
# chris paul
# deandre ayton
# deandre ayton
# devin booker
# devin booker
# devin booker
# devin booker
# chris paul
# chris paul
# deandre ayton
# deandre ayton
# deandre ayton
# deandre ayton
# devin booker
# devin booker
# 12880  Under   5.5   -151    4.435853  14.3
# 13010  Under   4.5   -124    3.315034  18.0
# 12999  Under   4.5   -123    3.315034  17.9
# 13018  Under   4.5   -130    3.315034  18.9
# 12974  Under   4.5   -120    3.315034  17.4
# 12986  Under   4.5   -128    3.315034  18.6
# 13014  Under   4.5   -135    3.315034  19.6
# 13006  Under   4.5   -124    3.315034  18.0
# 12996  Under   4.5   -123    3.315034  17.9
# 13001  Under   6.5   -108    5.138245  12.7
# 13020  Under   6.5   -115    5.138245  13.8
# 12976  Under   6.5   -105    5.138245  12.2
# 12982  Under   6.5   -115    5.138245  13.8
# 12994  Under   6.5   -108    5.138245  12.7
# 13012  Under   9.5   -137    7.827164  16.4
# 12997  Under   9.5   -143    7.827164  17.2
# 13022  Under   9.5   -135    7.827164  16.2
# 12984  Under   9.5   -138    7.827164  16.6
# 13016  Under   9.5   -125    7.827164  14.8
# 13008  Under   9.5   -127    7.827164  15.1
# 13079   Over   1.5   -165    2.513074  16.1
# 13118   Over   1.5   -164    2.513074  16.0
# 13296  Under   5.5   -150    4.515875  12.0
# 13202  Under   5.5   -145    4.515875  11.5
# 13222  Under   5.5   -150    4.515875  12.0
# 13314  Under   5.5   -145    4.515875  11.5
# 13256  Under   5.5   -136    4.515875  10.4
# 13276  Under   5.5   -145    4.515875  11.5
# 13240  Under   5.5   -125    4.471029  10.1
# 13258  Under   5.5   -125    4.471029  10.1
# 13342  Under   2.5   -185    2.003555  11.4
# 13353  Under   2.5   -179    2.003555  10.9
# 13402  Under   2.5   -170    2.003555  10.1
# 13324  Under   2.5   -175    2.003555  10.6
# 13340  Under   2.5   -170    2.003555  10.1
# 13394  Under   2.5   -175    2.003555  10.6
# 13366  Under   2.5   -179    2.003555  10.9
# 13346  Under   9.5   -120    7.978663  11.2
# 13359  Under   9.5   -125    7.978663  11.9
# 13408  Under   9.5   -115    7.978663  10.4
# 13330  Under   9.5   -120    7.978663  11.2
# 13374  Under   9.5   -117    7.978663  10.7
# 13433   Over   3.5   -160    4.994178  18.6
# 13516   Over   3.5   -159    4.994178  18.5
# 13451   Over   3.5   -155    4.994178  18.0
# 13477   Over   3.5   -160    4.994178  18.6
# 13432  Under   4.5   -160    3.576075  14.9
# 13513  Under   4.5   -156    3.576075  14.4
# 13454  Under   4.5   -155    3.576075  14.3
# 13486  Under   4.5   -160    3.576075  14.9
# 13557   Over   8.5   -109   10.809655  14.2
# 13545   Over   8.5   -110   10.809655  14.4
# 13586   Over   8.5   -111   10.809655  14.6
# 13595   Over   8.5   -115   10.809655  15.2
# 13525   Over   8.5   -110   10.809655  14.4
# 13535   Over   8.5   -113   10.809655  14.9
# 13577   Over   8.5   -115   10.809655  15.2
# 13565   Over   8.5   -109   10.809655  14.2
# 13569   Over   8.5   -113   10.809655  14.9
# 13614  Under  11.5   -127    9.515938  17.0
# 13630  Under  11.5   -125    9.515938  16.7
# 13608  Under  11.5   -125    9.515938  16.7
# 13648  Under  11.5   -130    9.515938  17.4
# 13620  Under  11.5   -127    9.515938  17.0
