# %% [markdown]
# # 3 Pointers Made against shooting.csv

# %% [markdown]
# ### Import packages

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline
from scipy.stats import pearsonr
import itertools

pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Set working directory

# %%
# Print working directory
cwd = os.getcwd()
print(f'Directory: {cwd}')

# Change working directory
os.chdir('/Users/tyler/OneDrive/Documents/Python/NBA')

# Print working directory
cwd = os.getcwd()
print(f'Directory: {cwd}')
# Out:
# Directory: C:\Users\tyler\OneDrive\Documents\Python\NBA\backend\analysis
# Directory: C:\Users\tyler\OneDrive\Documents\Python\NBA

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Import data

# %%
df = pd.read_csv('backend/data/shooting.csv').drop(['Unnamed: 0'], axis=1)
y = pd.read_csv('backend/data/scoring.csv').drop(['Unnamed: 0'], axis=1)[['date', 'visitor', 'home', 'team', 'q3']]
df = pd.merge(df, y, left_on=['date', 'visitor', 'home', 'team'], right_on=['date', 'visitor', 'home', 'team'])
df = df.rename({'q3': 'target'}, axis=1)

# %% [markdown]
# ### Basic exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194138 entries, 0 to 194137
# Data columns (total 18 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      194138 non-null  object
#  1   visitor   194138 non-null  object
#  2   home      194138 non-null  object
#  3   team      194138 non-null  int64
#  4   quarter   194138 non-null  object
#  5   fg        194138 non-null  int64
#  6   fga       194138 non-null  int64
#  7   fg_perc   194138 non-null  float64
#  8   2p        194138 non-null  int64
#  9   2pa       194138 non-null  int64
#  10  2p_perc   194135 non-null  float64
#  11  3p        194138 non-null  int64
#  12  3pa       194138 non-null  int64
#  13  3p_perc   192676 non-null  float64
#  14  efg_perc  194138 non-null  float64
#  15  ast       194138 non-null  int64
#  16  ast_perc  194116 non-null  float64
#  17  target    194138 non-null  int64
# dtypes: float64(5), int64(9), object(4)
# memory usage: 28.1+ MB

# %%
df.sample(5)
# Out:
#                      date               visitor              home  team  \
# 163285   Sat, Jan 5, 2019       Toronto Raptors   Milwaukee Bucks     1
# 193949  Sun, Jun 20, 2021  Los Angeles Clippers      Phoenix Suns     0
# 177382  Wed, Jan 22, 2020    Los Angeles Lakers   New York Knicks     0
# 60889    Sun, Feb 6, 2011    Philadelphia 76ers   New York Knicks     0
# 60288   Sat, Jan 29, 2011         Atlanta Hawks  Dallas Mavericks     0
#
#        quarter  fg  fga  fg_perc  2p  2pa  2p_perc  3p  3pa  3p_perc  \
# 163285   total  40   81    0.494  26   44    0.591  14   37    0.378
# 193949      q2  12   22    0.545   7   11    0.636   5   11    0.455
# 177382      q3  10   20    0.500   9   15    0.600   1    5    0.200
# 60889       q2  11   19    0.579  10   14    0.714   1    5    0.200
# 60288    total  35   76    0.461  31   56    0.554   4   20    0.200
#
#         efg_perc  ast  ast_perc  target
# 163285     0.580   29     0.725      25
# 193949     0.659    9     0.750      39
# 177382     0.525    6     0.600      28
# 60889      0.605    5     0.455      29
# 60288      0.487   20     0.571      29

# %%
# Convert 'date' column to Date object
df['date'] = pd.to_datetime(df['date'])

# Conver 'team' column to Team Name
df['team'] = np.where(df['team'], df['home'], df['visitor'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194138 entries, 0 to 194137
# Data columns (total 18 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      194138 non-null  datetime64[ns]
#  1   visitor   194138 non-null  object
#  2   home      194138 non-null  object
#  3   team      194138 non-null  object
#  4   quarter   194138 non-null  object
#  5   fg        194138 non-null  int64
#  6   fga       194138 non-null  int64
#  7   fg_perc   194138 non-null  float64
#  8   2p        194138 non-null  int64
#  9   2pa       194138 non-null  int64
#  10  2p_perc   194135 non-null  float64
#  11  3p        194138 non-null  int64
#  12  3pa       194138 non-null  int64
#  13  3p_perc   192676 non-null  float64
#  14  efg_perc  194138 non-null  float64
#  15  ast       194138 non-null  int64
#  16  ast_perc  194116 non-null  float64
#  17  target    194138 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(8), object(4)
# memory usage: 28.1+ MB

# %%
total_df = df[df['quarter'] == 'total']
q1_df = df[df['quarter'] == 'q1']
q2_df = df[df['quarter'] == 'q2']
q3_df = df[df['quarter'] == 'q3']
q4_df = df[df['quarter'] == 'q4']

# %%
q3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38288 entries, 2 to 194135
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      38288 non-null  datetime64[ns]
#  1   visitor   38288 non-null  object
#  2   home      38288 non-null  object
#  3   team      38288 non-null  object
#  4   quarter   38288 non-null  object
#  5   fg        38288 non-null  int64
#  6   fga       38288 non-null  int64
#  7   fg_perc   38288 non-null  float64
#  8   2p        38288 non-null  int64
#  9   2pa       38288 non-null  int64
#  10  2p_perc   38288 non-null  float64
#  11  3p        38288 non-null  int64
#  12  3pa       38288 non-null  int64
#  13  3p_perc   37996 non-null  float64
#  14  efg_perc  38288 non-null  float64
#  15  ast       38288 non-null  int64
#  16  ast_perc  38287 non-null  float64
#  17  target    38288 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(8), object(4)
# memory usage: 5.6+ MB

# %% [markdown]
# ### First half dataframe

# %%
h1_df = df[(df['quarter'] == 'q1') | (df['quarter'] == 'q2')]
h1_df = h1_df.groupby(['date', 'home', 'visitor', 'team']).aggregate(['sum', 'mean'])
h1_cols = [col 
           for col in h1_df.columns
           if ('_perc' in col[0] and 'mean' == col[1]) or ('_perc' not in col[0] and 'sum' == col[1])]
h1_df = h1_df[h1_cols]
h1_df.columns = [col[0] for col in h1_df.columns]
h1_df = h1_df.reset_index()
h1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38288 entries, 0 to 38287
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      38288 non-null  datetime64[ns]
#  1   home      38288 non-null  object
#  2   visitor   38288 non-null  object
#  3   team      38288 non-null  object
#  4   fg        38288 non-null  int64
#  5   fga       38288 non-null  int64
#  6   fg_perc   38288 non-null  float64
#  7   2p        38288 non-null  int64
#  8   2pa       38288 non-null  int64
#  9   2p_perc   38288 non-null  float64
#  10  3p        38288 non-null  int64
#  11  3pa       38288 non-null  int64
#  12  3p_perc   38274 non-null  float64
#  13  efg_perc  38288 non-null  float64
#  14  ast       38288 non-null  int64
#  15  ast_perc  38288 non-null  float64
#  16  target    38288 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(8), object(3)
# memory usage: 5.0+ MB

# %% [markdown]
# ### 3Q Pts vs Year (--)

# %%
# Create year and month columns
q3_df.loc[:, 'year'] = q3_df.loc[:, 'date'].dt.year
q3_df.loc[:, 'month'] = q3_df.loc[:, 'date'].dt.month

# Change plot size
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))
fig.suptitle('3Q Pts vs Time')
fig = plt.gcf()

# Plot lineplot of Total 3pt Made over Time
chart = sns.lineplot(x='year', y='target', data=q3_df, ax= ax[0, 0]).set(title='Line Plot')

# Plot boxplot of Total 3pt Made over Time
chart = sns.boxplot(x='year', y='target', data=q3_df, ax=ax[0, 1]).set(title= 'Box Plot')
plt.xticks(rotation=45)

# Plot distribution plot of Total 3pt Made over Time
chart = sns.kdeplot(x='target', data=q3_df, ax=ax[1,0]).set(title='Distribution Plot')

# Plot linearregression of Total 3pt Made over Time
chart = sns.regplot(x='year', y='target', data=q3_df, ax=ax[1, 1]).set(title='Linear Regression')

plt.show()
# Out:
# c:\python38\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# ### 3Q Pts vs Year (2015 - current)

# %%
# Change plot size
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))
fig.suptitle('3Q Pts vs Time')
fig = plt.gcf()

year = 2015

# Plot lineplot of Total 3pt Made over Time
chart = sns.lineplot(x='year', y='target', data=q3_df[q3_df['year'] >= year], ax= ax[0, 0]).set(title='Line Plot')

# Plot boxplot of Total 3pt Made over Time
chart = sns.boxplot(x='year', y='target', data=q3_df[q3_df['year'] >= year], ax=ax[0, 1]).set(title= 'Box Plot')
plt.xticks(rotation=45)

# Plot distribution plot of Total 3pt Made over Time
chart = sns.kdeplot(x='target', data=q3_df[q3_df['year'] >= year], ax=ax[1,0]).set(title='Distribution Plot')

# Plot linearregression of Total 3pt Made over Time
chart = sns.regplot(x='year', y='target', data=q3_df[q3_df['year'] >= year], ax=ax[1, 1]).set(title='Linear Regression')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Dataframe of team's last 15 performances

# %%
# Totals
q3_df = df[df['quarter'] == 'q3'].copy()

# Return ten lastest dates team played
def last_15_date(team, date):
    schedule = q3_df[q3_df['team'] == team].sort_values(by='date').reset_index()
    date_index = schedule[schedule['date'] == date].index[0]
    if date_index - 15 < 0:
        return None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
    else:
        date_1, date_2 = schedule.iloc[date_index - 1]['date'], schedule.iloc[date_index - 2]['date']
        date_3, date_4 = schedule.iloc[date_index - 3]['date'], schedule.iloc[date_index - 4]['date']
        date_5, date_6 = schedule.iloc[date_index - 5]['date'], schedule.iloc[date_index - 6]['date']
        date_7, date_8 = schedule.iloc[date_index - 7]['date'], schedule.iloc[date_index - 8]['date']
        date_9, date_10 = schedule.iloc[date_index - 9]['date'], schedule.iloc[date_index - 10]['date']
        date_11, date_12 = schedule.iloc[date_index - 11]['date'], schedule.iloc[date_index - 12]['date']
        date_13, date_14 = schedule.iloc[date_index - 13]['date'], schedule.iloc[date_index - 14]['date']
        date_15 = schedule.iloc[date_index - 15]['date']
        return date_1, date_2, date_3, date_4, date_5, date_6, date_7, date_8, date_9, date_10, date_11, date_12, date_13, date_14, date_15

q3_df['dates'] = q3_df.apply(lambda x: last_15_date(x.team, x.date), axis=1)
q3_df['date_1'], q3_df['date_2'] = q3_df['dates'].apply(lambda x: x[0]), q3_df['dates'].apply(lambda x: x[1])
q3_df['date_3'], q3_df['date_4'] = q3_df['dates'].apply(lambda x: x[2]), q3_df['dates'].apply(lambda x: x[3])
q3_df['date_5'], q3_df['date_6'] = q3_df['dates'].apply(lambda x: x[4]), q3_df['dates'].apply(lambda x: x[5])
q3_df['date_7'], q3_df['date_8'] = q3_df['dates'].apply(lambda x: x[6]), q3_df['dates'].apply(lambda x: x[7])
q3_df['date_9'], q3_df['date_10'] = q3_df['dates'].apply(lambda x: x[8]), q3_df['dates'].apply(lambda x: x[9])
q3_df['date_11'], q3_df['date_12'] = q3_df['dates'].apply(lambda x: x[10]), q3_df['dates'].apply(lambda x: x[11])
q3_df['date_13'], q3_df['date_14'] = q3_df['dates'].apply(lambda x: x[12]), q3_df['dates'].apply(lambda x: x[13])
q3_df['date_15'] = q3_df['dates'].apply(lambda x: x[14])

# %%
# X and y column names to merge on
x_cols = ['date', 'team', 'fg', 'fga', 'fg_perc', '2p', '2pa', '2p_perc',
          '3p', '3pa', '3p_perc', 'efg_perc', 'ast', 'ast_perc']

last_15_games = q3_df.copy()
X = total_df[x_cols].copy()

# Dataframe of target (3pt made by each team) and of variables (last 5 games stats for each team)
dates = ['_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '_10', '_11', '_12', '_13', '_14', '_15']
for date in dates:
    last_15_games = pd.merge(last_15_games, X, left_on=['date' + date, 'team'], right_on=['date', 'team'], how='left', suffixes=('', date))

# %% [markdown]
# ## Feature Engineering

# %%
# Create season variable
def season(month, year):
    if (month in list(range(10, 13)) and year == 2006) or (month in list(range(1, 7)) and year == 2007):
        return 2006
    elif (month in list(range(10, 13)) and year == 2007) or (month in list(range(1, 7)) and year == 2008):
        return 2007
    elif (month in list(range(10, 13)) and year == 2008) or (month in list(range(1, 7)) and year == 2009):
        return 2008
    elif (month in list(range(10, 13)) and year == 2009) or (month in list(range(1, 7)) and year == 2010):
        return 2009
    elif (month in list(range(10, 13)) and year == 2010) or (month in list(range(1, 7)) and year == 2011):
        return 2010
    elif (month in list(range(10, 11)) and year == 2011) or (month in list(range(1, 7)) and year == 2012):
        return 2011
    elif (month in list(range(10, 13)) and year == 2012) or (month in list(range(1, 7)) and year == 2013):
        return 2012
    elif (month in list(range(10, 13)) and year == 2013) or (month in list(range(1, 7)) and year == 2014):
        return 2013
    elif (month in list(range(10, 13)) and year == 2014) or (month in list(range(1, 7)) and year == 2015):
        return 2014
    elif (month in list(range(10, 13)) and year == 2015) or (month in list(range(1, 7)) and year == 2016):
        return 2015
    elif (month in list(range(10, 13)) and year == 2016) or (month in list(range(1, 7)) and year == 2017):
        return 2016
    elif (month in list(range(10, 13)) and year == 2017) or (month in list(range(1, 7)) and year == 2018):
        return 2017
    elif (month in list(range(10, 13)) and year == 2018) or (month in list(range(1, 7)) and year == 2019):
        return 2018
    elif (month in list(range(10, 13)) and year == 2019) or (month in list(range(1, 11)) and year == 2020):
        return 2019
    elif (month in list(range(12, 13)) and year == 2020) or (month in list(range(1, 8)) and year == 2021):
        return 2020

q3_df['season'] = q3_df['date'].apply(lambda x: season(x.month, x.year))
last_15_games['season'] = last_15_games['date'].apply(lambda x: season(x.month, x.year))
last_15_games.sample()
# Out:
#             date         visitor              home              team quarter  \
# 27061 2017-01-18  Indiana Pacers  Sacramento Kings  Sacramento Kings      q3
#
#        fg  fga  fg_perc  2p  2pa  2p_perc  3p  3pa  3p_perc  efg_perc  ast  \
# 27061   7   20     0.35   5   17    0.294   2    3    0.667       0.4    5
#
#        ast_perc  target                                              dates  \
# 27061     0.714      19  (2017-01-15 00:00:00, 2017-01-13 00:00:00, 201...
#
#           date_1     date_2     date_3     date_4     date_5     date_6  \
# 27061 2017-01-15 2017-01-13 2017-01-10 2017-01-08 2017-01-06 2017-01-04
#
#           date_7     date_8     date_9    date_10    date_11    date_12  \
# 27061 2017-01-03 2016-12-31 2016-12-28 2016-12-26 2016-12-23 2016-12-21
#
#          date_13    date_14    date_15  season     date_1  fg_1  fga_1  \
# 27061 2016-12-20 2016-12-18 2016-12-16  2016.0 2017-01-15  37.0   81.0
#
#        fg_perc_1  2p_1  2pa_1  2p_perc_1  3p_1  3pa_1  3p_perc_1  efg_perc_1  \
# 27061      0.457  28.0   56.0        0.5   9.0   25.0       0.36       0.512
#
#        ast_1  ast_perc_1     date_2  fg_2  fga_2  fg_perc_2  2p_2  2pa_2  \
# 27061   24.0       0.649 2017-01-13  42.0   80.0      0.525  33.0   55.0
#
#        2p_perc_2  3p_2  3pa_2  3p_perc_2  efg_perc_2  ast_2  ast_perc_2  \
# 27061        0.6   9.0   25.0       0.36       0.581   23.0       0.548
#
#           date_3  fg_3  fga_3  fg_perc_3  2p_3  2pa_3  2p_perc_3  3p_3  3pa_3  \
# 27061 2017-01-10  32.0   74.0      0.432  19.0   50.0       0.38  13.0   24.0
#
#        3p_perc_3  efg_perc_3  ast_3  ast_perc_3     date_4  fg_4  fga_4  \
# 27061      0.542        0.52   21.0       0.656 2017-01-08  36.0   74.0
#
#        fg_perc_4  2p_4  2pa_4  2p_perc_4  3p_4  3pa_4  3p_perc_4  efg_perc_4  \
# 27061      0.486  25.0   46.0      0.543  11.0   28.0      0.393       0.561
#
#        ast_4  ast_perc_4     date_5  fg_5  fga_5  fg_perc_5  2p_5  2pa_5  \
# 27061   21.0       0.583 2017-01-06  36.0   87.0      0.414  27.0   57.0
#
#        2p_perc_5  3p_5  3pa_5  3p_perc_5  efg_perc_5  ast_5  ast_perc_5  \
# 27061      0.474   9.0   30.0        0.3       0.466   23.0       0.639
#
#           date_6  fg_6  fga_6  fg_perc_6  2p_6  2pa_6  2p_perc_6  3p_6  3pa_6  \
# 27061 2017-01-04  40.0   78.0      0.513  32.0   58.0      0.552   8.0   20.0
#
#        3p_perc_6  efg_perc_6  ast_6  ast_perc_6     date_7  fg_7  fga_7  \
# 27061        0.4       0.564   26.0        0.65 2017-01-03  46.0   88.0
#
#        fg_perc_7  2p_7  2pa_7  2p_perc_7  3p_7  3pa_7  3p_perc_7  efg_perc_7  \
# 27061      0.523  35.0   59.0      0.593  11.0   29.0      0.379       0.585
#
#        ast_7  ast_perc_7     date_8  fg_8  fga_8  fg_perc_8  2p_8  2pa_8  \
# 27061   26.0       0.565 2016-12-31  31.0   72.0      0.431  20.0   44.0
#
#        2p_perc_8  3p_8  3pa_8  3p_perc_8  efg_perc_8  ast_8  ast_perc_8  \
# 27061      0.455  11.0   28.0      0.393       0.507   17.0       0.548
#
#           date_9  fg_9  fga_9  fg_perc_9  2p_9  2pa_9  2p_perc_9  3p_9  3pa_9  \
# 27061 2016-12-28  31.0   79.0      0.392  22.0   51.0      0.431   9.0   28.0
#
#        3p_perc_9  efg_perc_9  ast_9  ast_perc_9    date_10  fg_10  fga_10  \
# 27061      0.321       0.449   20.0       0.645 2016-12-26   39.0    87.0
#
#        fg_perc_10  2p_10  2pa_10  2p_perc_10  3p_10  3pa_10  3p_perc_10  \
# 27061       0.448   32.0    62.0       0.516    7.0    25.0        0.28
#
#        efg_perc_10  ast_10  ast_perc_10    date_11  fg_11  fga_11  fg_perc_11  \
# 27061        0.489    24.0        0.615 2016-12-23   42.0    80.0       0.525
#
#        2p_11  2pa_11  2p_perc_11  3p_11  3pa_11  3p_perc_11  efg_perc_11  \
# 27061   27.0    51.0       0.529   15.0    29.0       0.517        0.619
#
#        ast_11  ast_perc_11    date_12  fg_12  fga_12  fg_perc_12  2p_12  \
# 27061    27.0        0.643 2016-12-21   34.0    74.0       0.459   24.0
#
#        2pa_12  2p_perc_12  3p_12  3pa_12  3p_perc_12  efg_perc_12  ast_12  \
# 27061    53.0       0.453   10.0    21.0       0.476        0.527    13.0
#
#        ast_perc_12    date_13  fg_13  fga_13  fg_perc_13  2p_13  2pa_13  \
# 27061        0.382 2016-12-20   40.0    72.0       0.556   30.0    49.0
#
#        2p_perc_13  3p_13  3pa_13  3p_perc_13  efg_perc_13  ast_13  \
# 27061       0.612   10.0    23.0       0.435        0.625    20.0
#
#        ast_perc_13    date_14  fg_14  fga_14  fg_perc_14  2p_14  2pa_14  \
# 27061          0.5 2016-12-18   30.0    76.0       0.395   22.0    45.0
#
#        2p_perc_14  3p_14  3pa_14  3p_perc_14  efg_perc_14  ast_14  \
# 27061       0.489    8.0    31.0       0.258        0.447    16.0
#
#        ast_perc_14    date_15  fg_15  fga_15  fg_perc_15  2p_15  2pa_15  \
# 27061        0.533 2016-12-16   31.0    80.0       0.388   24.0    56.0
#
#        2p_perc_15  3p_15  3pa_15  3p_perc_15  efg_perc_15  ast_15  ast_perc_15
# 27061       0.429    7.0    24.0       0.292        0.431    18.0        0.581

# %%
# Calculate z-score
def z_score(value, mean, std):
    return (value - mean) / std

# %%
# Season average for each stat
season_avgs = q3_df.groupby(['team', 'season']).aggregate(['mean', 'std']).reset_index()
season_avgs.columns = ["_".join([tup[0], tup[1]]) if len(tup[1]) > 0 else tup[0] for tup in season_avgs.columns]
last_15_games = pd.merge(last_15_games, season_avgs, left_on=['team', 'season'], right_on=['team', 'season'])
last_15_games.sample()
# Out:
#             date                 visitor            home  \
# 25539 2015-12-11  Minnesota Timberwolves  Denver Nuggets
#
#                          team quarter  fg  fga  fg_perc  2p  2pa  2p_perc  3p  \
# 25539  Minnesota Timberwolves      q3   8   16      0.5   7   13    0.538   1
#
#        3pa  3p_perc  efg_perc  ast  ast_perc  target  \
# 25539    3    0.333     0.531    2      0.25      22
#
#                                                    dates     date_1  \
# 25539  (2015-12-09 00:00:00, 2015-12-07 00:00:00, 201... 2015-12-09
#
#           date_2     date_3     date_4     date_5     date_6     date_7  \
# 25539 2015-12-07 2015-12-05 2015-12-01 2015-11-29 2015-11-27 2015-11-25
#
#           date_8     date_9    date_10    date_11    date_12    date_13  \
# 25539 2015-11-23 2015-11-20 2015-11-18 2015-11-17 2015-11-15 2015-11-13
#
#          date_14    date_15  season     date_1  fg_1  fga_1  fg_perc_1  2p_1  \
# 25539 2015-11-12 2015-11-10  2015.0 2015-12-09  46.0   93.0      0.495  39.0
#
#        2pa_1  2p_perc_1  3p_1  3pa_1  3p_perc_1  efg_perc_1  ast_1  \
# 25539   74.0      0.527   7.0   19.0      0.368       0.532   30.0
#
#        ast_perc_1     date_2  fg_2  fga_2  fg_perc_2  2p_2  2pa_2  2p_perc_2  \
# 25539       0.652 2015-12-07  36.0   82.0      0.439  29.0   64.0      0.453
#
#        3p_2  3pa_2  3p_perc_2  efg_perc_2  ast_2  ast_perc_2     date_3  fg_3  \
# 25539   7.0   18.0      0.389       0.482   18.0         0.5 2015-12-05  38.0
#
#        fga_3  fg_perc_3  2p_3  2pa_3  2p_perc_3  3p_3  3pa_3  3p_perc_3  \
# 25539   83.0      0.458  33.0   68.0      0.485   5.0   15.0      0.333
#
#        efg_perc_3  ast_3  ast_perc_3     date_4  fg_4  fga_4  fg_perc_4  2p_4  \
# 25539       0.488   24.0       0.632 2015-12-01  29.0   77.0      0.377  25.0
#
#        2pa_4  2p_perc_4  3p_4  3pa_4  3p_perc_4  efg_perc_4  ast_4  \
# 25539   58.0      0.431   4.0   19.0      0.211       0.403   14.0
#
#        ast_perc_4     date_5  fg_5  fga_5  fg_perc_5  2p_5  2pa_5  2p_perc_5  \
# 25539       0.483 2015-11-29  37.0   82.0      0.451  29.0   66.0      0.439
#
#        3p_5  3pa_5  3p_perc_5  efg_perc_5  ast_5  ast_perc_5     date_6  fg_6  \
# 25539   8.0   16.0        0.5         0.5   21.0       0.568 2015-11-27  37.0
#
#        fga_6  fg_perc_6  2p_6  2pa_6  2p_perc_6  3p_6  3pa_6  3p_perc_6  \
# 25539   77.0      0.481  28.0   52.0      0.538   9.0   25.0       0.36
#
#        efg_perc_6  ast_6  ast_perc_6     date_7  fg_7  fga_7  fg_perc_7  2p_7  \
# 25539       0.539   20.0       0.541 2015-11-25  34.0   82.0      0.415  25.0
#
#        2pa_7  2p_perc_7  3p_7  3pa_7  3p_perc_7  efg_perc_7  ast_7  \
# 25539   61.0       0.41   9.0   21.0      0.429        0.47   22.0
#
#        ast_perc_7     date_8  fg_8  fga_8  fg_perc_8  2p_8  2pa_8  2p_perc_8  \
# 25539       0.647 2015-11-23  36.0   78.0      0.462  33.0   66.0        0.5
#
#        3p_8  3pa_8  3p_perc_8  efg_perc_8  ast_8  ast_perc_8     date_9  fg_9  \
# 25539   3.0   12.0       0.25       0.481   20.0       0.556 2015-11-20  33.0
#
#        fga_9  fg_perc_9  2p_9  2pa_9  2p_perc_9  3p_9  3pa_9  3p_perc_9  \
# 25539   77.0      0.429  30.0   64.0      0.469   3.0   13.0      0.231
#
#        efg_perc_9  ast_9  ast_perc_9    date_10  fg_10  fga_10  fg_perc_10  \
# 25539       0.448   17.0       0.515 2015-11-18   36.0    85.0       0.424
#
#        2p_10  2pa_10  2p_perc_10  3p_10  3pa_10  3p_perc_10  efg_perc_10  \
# 25539   32.0    67.0       0.478    4.0    18.0       0.222        0.447
#
#        ast_10  ast_perc_10    date_11  fg_11  fga_11  fg_perc_11  2p_11  \
# 25539    21.0        0.583 2015-11-17   36.0    97.0       0.371   32.0
#
#        2pa_11  2p_perc_11  3p_11  3pa_11  3p_perc_11  efg_perc_11  ast_11  \
# 25539    76.0       0.421    4.0    21.0        0.19        0.392    14.0
#
#        ast_perc_11    date_12  fg_12  fga_12  fg_perc_12  2p_12  2pa_12  \
# 25539        0.389 2015-11-15   41.0    82.0         0.5   36.0    66.0
#
#        2p_perc_12  3p_12  3pa_12  3p_perc_12  efg_perc_12  ast_12  \
# 25539       0.545    5.0    16.0       0.312         0.53    20.0
#
#        ast_perc_12    date_13  fg_13  fga_13  fg_perc_13  2p_13  2pa_13  \
# 25539        0.488 2015-11-13   42.0    83.0       0.506   35.0    63.0
#
#        2p_perc_13  3p_13  3pa_13  3p_perc_13  efg_perc_13  ast_13  \
# 25539       0.556    7.0    20.0        0.35        0.548    16.0
#
#        ast_perc_13    date_14  fg_14  fga_14  fg_perc_14  2p_14  2pa_14  \
# 25539        0.381 2015-11-12   43.0    87.0       0.494   40.0    78.0
#
#        2p_perc_14  3p_14  3pa_14  3p_perc_14  efg_perc_14  ast_14  \
# 25539       0.513    3.0     9.0       0.333        0.511    21.0
#
#        ast_perc_14    date_15  fg_15  fga_15  fg_perc_15  2p_15  2pa_15  \
# 25539        0.488 2015-11-10   36.0    80.0        0.45   27.0    61.0
#
#        2p_perc_15  3p_15  3pa_15  3p_perc_15  efg_perc_15  ast_15  \
# 25539       0.443    9.0    19.0       0.474        0.506    25.0
#
#        ast_perc_15   fg_mean    fg_std   fga_mean   fga_std  fg_perc_mean  \
# 25539        0.694  9.195122  2.213533  19.682927  2.810378      0.471012
#
#        fg_perc_std   2p_mean    2p_std   2pa_mean   2pa_std  2p_perc_mean  \
# 25539     0.108525  8.012195  2.180123  15.768293  2.750079      0.512988
#
#        2p_perc_std   3p_mean    3p_std  3pa_mean  3pa_std  3p_perc_mean  \
# 25539     0.128489  1.182927  0.957466  3.914634   1.7861      0.305537
#
#        3p_perc_std  efg_perc_mean  efg_perc_std  ast_mean   ast_std  \
# 25539       0.2406       0.501244      0.115843  5.878049  2.311486
#
#        ast_perc_mean  ast_perc_std  target_mean  target_std
# 25539       0.634012      0.190285    24.646341    5.371098

# %%
stats = ['fg', 'fga', 'fg_perc', '2p', '2pa', '2p_perc', '3p', '3pa', '3p_perc', 'efg_perc', 'ast', 'ast_perc']

for stat in stats:
    # 3 day trend
    last_15_games[stat + '_trend_3'] = \
        (z_score(last_15_games[stat + '_1'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_2'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_3'], last_15_games[stat + '_mean'], last_15_games[stat + '_std'])) / 3
    
    # 5 day trend
    last_15_games[stat + '_trend_5'] = \
        (z_score(last_15_games[stat + '_1'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_2'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_3'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_4'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_5'], last_15_games[stat + '_mean'], last_15_games[stat + '_std'])) / 5
    
    # 10 day trend
    last_15_games[stat + '_trend_10'] = \
        (z_score(last_15_games[stat + '_1'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_2'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_3'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_4'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_5'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_6'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_7'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_8'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_9'], last_15_games[stat + '_mean'], last_15_games[stat + '_std']) + \
         z_score(last_15_games[stat + '_10'], last_15_games[stat + '_mean'], last_15_games[stat + '_std'])) / 10

# %% [markdown]
# ### Last Performance

# %%
stats = ['fg', 'fga', 'fg_perc', '2p', '2pa', '2p_perc', '3p', '3pa', '3p_perc', 'efg_perc', 'ast', 'ast_perc']
dates = ['_1']
trends = ['_trend_3', '_trend_5', '_trend_10']
cols = ['date', 'visitor', 'home', 'team', 'target'] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, dates))] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, trends))]

last_game = last_15_games[cols].copy()

for stat in stats:
    last_game[stat] = 0
    for date in dates:
        last_game[stat] = last_game[stat] + last_game[stat + date]
    
    last_game[stat] = last_game[stat] / len(dates)

last_game = last_game.dropna(axis=0)
last_game.sample(5)
# Out:
#             date                visitor                    home  \
# 28389 2018-04-30     Philadelphia 76ers          Boston Celtics
# 23217 2016-03-14          Chicago Bulls         Toronto Raptors
# 23202 2016-02-06          Chicago Bulls  Minnesota Timberwolves
# 10114 2010-02-06  Oklahoma City Thunder   Golden State Warriors
# 33603 2020-02-21   New Orleans Pelicans  Portland Trail Blazers
#
#                         team  target  fg_1  fga_1  fg_perc_1  2p_1  2pa_1  \
# 28389         Boston Celtics      31  45.0   84.0      0.536  36.0   58.0
# 23217          Chicago Bulls      26  38.0   81.0      0.469  30.0   60.0
# 23202          Chicago Bulls      29  43.0   93.0      0.462  38.0   81.0
# 10114  Golden State Warriors      23  38.0   77.0      0.494  32.0   61.0
# 33603   New Orleans Pelicans      29  42.0   86.0      0.488  28.0   51.0
#
#        2p_perc_1  3p_1  3pa_1  3p_perc_1  efg_perc_1  ast_1  ast_perc_1  \
# 28389      0.621   9.0   26.0      0.346       0.589   28.0       0.622
# 23217      0.500   8.0   21.0      0.381       0.519   27.0       0.711
# 23202      0.469   5.0   12.0      0.417       0.489   21.0       0.488
# 10114      0.525   6.0   16.0      0.375       0.532   13.0       0.342
# 33603      0.549  14.0   35.0      0.400       0.570   31.0       0.738
#
#        fg_trend_3  fg_trend_5  fg_trend_10  fga_trend_3  fga_trend_5  \
# 28389   10.286901   10.178264    11.644863    19.319566    20.063811
# 23217   12.495998   12.210733    12.638631    19.821091    20.789597
# 23202   13.351793   13.836744    13.109318    22.682586    23.166839
# 10114   11.123900   12.098649    11.636926    21.708019    22.029267
# 33603   13.094995   12.865965    12.865965    20.050866    20.286086
#
#        fga_trend_10  fg_perc_trend_3  fg_perc_trend_5  fg_perc_trend_10  \
# 28389     21.890596        -0.089968        -0.217309         -0.080872
# 23217     21.317873         0.378591         0.148632          0.180571
# 23202     22.803650         0.123081         0.176312          0.049622
# 10114     22.958591         0.030721         0.209546          0.001953
# 33603     20.050866         0.186384         0.112025          0.136616
#
#        2p_trend_3  2p_trend_5  2p_trend_10  2pa_trend_3  2pa_trend_5  \
+ \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, dates))] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, trends))]

last_5_games = last_15_games[cols].copy()

for stat in stats:
    last_5_games[stat] = 0
    for date in dates:
        last_5_games[stat] = last_5_games[stat] + last_5_games[stat + date]
    
    last_5_games[stat] = last_5_games[stat] / len(dates)

last_5_games = last_5_games.dropna(axis=0)
last_5_games.head()
# Out:
#          date                 visitor           home           team  target  \
# 15 2006-12-02      Washington Wizards  Chicago Bulls  Chicago Bulls      30
# 16 2006-12-04          Boston Celtics  Chicago Bulls  Chicago Bulls      25
# 17 2006-12-06      Philadelphia 76ers  Chicago Bulls  Chicago Bulls      27
# 18 2006-12-08         Toronto Raptors  Chicago Bulls  Chicago Bulls      24
# 19 2006-12-09  Minnesota Timberwolves  Chicago Bulls  Chicago Bulls      22
#
#     fg_1  fg_2  fg_3  fg_4  fg_5  fga_1  fga_2  fga_3  fga_4  fga_5  \
# 15  41.0  37.0  38.0  40.0  39.0   86.0   84.0   84.0   73.0   90.0
# 16  41.0  41.0  37.0  38.0  40.0   81.0   86.0   84.0   84.0   73.0
# 17  37.0  41.0  41.0  37.0  38.0   79.0   81.0   86.0   84.0   84.0
# 18  48.0  37.0  41.0  41.0  37.0   78.0   79.0   81.0   86.0   84.0
# 19  35.0  48.0  37.0  41.0  41.0   74.0   78.0   79.0   81.0   86.0
#
#     fg_perc_1  fg_perc_2  fg_perc_3  fg_perc_4  fg_perc_5  2p_1  2p_2  2p_3  \
# 15      0.477      0.440      0.452      0.548      0.433  29.0  30.0  33.0
# 16      0.506      0.477      0.440      0.452      0.548  32.0  29.0  30.0
# 17      0.468      0.506      0.477      0.440      0.452  33.0  32.0  29.0
# 18      0.615      0.468      0.506      0.477      0.440  42.0  33.0  32.0
# 19      0.473      0.615      0.468      0.506      0.477  30.0  42.0  33.0
#
#     2p_4  2p_5  2pa_1  2pa_2  2pa_3  2pa_4  2pa_5  2p_perc_1  2p_perc_2  \
# 15  34.0  31.0   65.0   69.0   67.0   60.0   66.0      0.446      0.435
# 16  33.0  34.0   58.0   65.0   69.0   67.0   60.0      0.552      0.446
# 17  30.0  33.0   61.0   58.0   65.0   69.0   67.0      0.541      0.552
# 18  29.0  30.0   65.0   61.0   58.0   65.0   69.0      0.646      0.541
# 19  32.0  29.0   56.0   65.0   61.0   58.0   65.0      0.536      0.646
#
#     2p_perc_3  2p_perc_4  2p_perc_5  3p_1  3p_2  3p_3  3p_4  3p_5  3pa_1  \
# 15      0.493      0.567      0.470  12.0   7.0   5.0   6.0   8.0   21.0
# 16      0.435      0.493      0.567   9.0  12.0   7.0   5.0   6.0   23.0
# 17      0.446      0.435      0.493   4.0   9.0  12.0   7.0   5.0   18.0
# 18      0.552      0.446      0.435   6.0   4.0   9.0  12.0   7.0   13.0
# 19      0.541      0.552      0.446   5.0   6.0   4.0   9.0  12.0   18.0
#
#     3pa_2  3pa_3  3pa_4  3pa_5  3p_perc_1  3p_perc_2  3p_perc_3  3p_perc_4  \
# 15   15.0   17.0   13.0   24.0      0.571      0.467      0.294      0.462
#
#     3pa_trend_5  3pa_trend_10  3p_perc_trend_3  3p_perc_trend_5  \
# 15     6.542907      5.709441         0.268915         0.196800
# 16     6.450300      6.079870         0.394275         0.241775
# 17     6.913336      6.450300         0.077644         0.055674
# 18     6.542907      6.126174        -0.063224         0.185944
# 19     6.820729      6.542907        -0.209262         0.039390
#
#     3p_perc_trend_10  efg_perc_trend_3  efg_perc_trend_5  efg_perc_trend_10  \
# 15          0.145623          0.121478          0.223962          -0.056009
# 16          0.142133          0.350493          0.368242           0.065941
# 17          0.111892          0.384845          0.205068           0.085694
# 18          0.155315          0.691153          0.500498           0.229115
# 19          0.047532          0.533705          0.543438           0.241138
#
#     ast_trend_3  ast_trend_5  ast_trend_10  ast_perc_trend_3  \
# 15     9.153890     8.844273      7.605805          0.004645
# 16    10.185946     9.463506      8.018628          0.198722
# 17    10.357955     9.669918      8.276642          0.249107
# 18    11.045993    10.392357      8.999081          0.237910
# 19    10.013936    10.392357      9.205492          0.137140
#
#     ast_perc_trend_5  ast_perc_trend_10    fg   fga  fg_perc    2p   2pa  \
# 15         -0.107696          -0.198389  39.0  83.4   0.4700  31.4  65.4
# 16          0.025546          -0.177115  39.4  81.6   0.4846  31.6  63.8
# 17          0.134154          -0.087541  38.8  82.8   0.4686  31.4  64.0
# 18          0.162146           0.010430  40.8  81.6   0.5012  33.2  63.6
# 19          0.200215           0.057456  40.4  79.6   0.5078  33.2  61.0
#
#     2p_perc   3p   3pa  3p_perc  efg_perc   ast  ast_perc
# 15   0.4822  7.6  18.0   0.4254    0.5156  22.4    0.5746
# 16   0.4986  7.8  17.8   0.4370    0.5324  23.6    0.5984
# 17   0.4934  7.4  18.8   0.3890    0.5134  24.0    0.6178
# 18   0.5240  7.6  18.0   0.4226    0.5478  25.4    0.6228
# 19   0.5442  7.2  18.6   0.3848    0.5528  25.4    0.6296

# %% [markdown]
# ### Last 10 Perfomances

# %%
stats = ['fg', 'fga', 'fg_perc', '2p', '2pa', '2p_perc', '3p', '3pa', '3p_perc', 'efg_perc', 'ast', 'ast_perc']
dates = ['_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '_10']
trends = ['_trend_3', '_trend_5', '_trend_10']
cols = ['date', 'visitor', 'home', 'team', 'target'] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, dates))] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, trends))]

last_10_games = last_15_games[cols].copy()

for stat in stats:
    last_10_games[stat] = 0
    for date in dates:
        last_10_games[stat] = last_10_games[stat] + last_10_games[stat + date]
    
    last_10_games[stat] = last_10_games[stat] / len(dates)

last_10_games = last_10_games.dropna(axis=0)
last_10_games.head()
# Out:
#          date                 visitor           home           team  target  \
# 15 2006-12-02      Washington Wizards  Chicago Bulls  Chicago Bulls      30
# 16 2006-12-04          Boston Celtics  Chicago Bulls  Chicago Bulls      25
# 17 2006-12-06      Philadelphia 76ers  Chicago Bulls  Chicago Bulls      27
# 18 2006-12-08         Toronto Raptors  Chicago Bulls  Chicago Bulls      24
# 19 2006-12-09  Minnesota Timberwolves  Chicago Bulls  Chicago Bulls      22
#
#     fg_1  fg_2  fg_3  fg_4  fg_5  fg_6  fg_7  fg_8  fg_9  fg_10  fga_1  fga_2  \
# 15  41.0  37.0  38.0  40.0  39.0  27.0  33.0  35.
# 18          0.500498           0.229115    11.045993    10.392357
# 19          0.543438           0.241138    10.013936    10.392357
#
#     ast_trend_10  ast_perc_trend_3  ast_perc_trend_5  ast_perc_trend_10    fg  \
# 15      7.605805          0.004645         -0.107696          -0.198389  36.0
# 16      8.018628          0.198722          0.025546          -0.177115  37.0
# 17      8.276642          0.249107          0.134154          -0.087541  36.8
# 18      8.999081          0.237910          0.162146           0.010430  38.1
# 19      9.205492          0.137140          0.200215           0.057456  38.3
#
#      fga  fg_perc    2p   2pa  2p_perc   3p   3pa  3p_perc  efg_perc   ast  \
# 15  81.5   0.4425  29.4  65.3   0.4506  6.6  16.2   0.4122    0.4830  20.0
# 16  81.5   0.4548  30.1  64.5   0.4679  6.9  17.0   0.4113    0.4972  20.8
# 17  80.8   0.4563  29.8  63.0   0.4746  7.0  17.8   0.4035    0.4995  21.3
# 18  80.7   0.4735  31.2  63.6   0.4917  6.9  17.1   0.4147    0.5162  22.7
# 19  80.9   0.4750  31.4  62.9   0.5009  6.9  18.0   0.3869    0.5176  23.1
#
#     ast_perc
# 15    0.5584
# 16    0.5622
# 17    0.5782
# 18    0.5957
# 19    0.6041

# %% [markdown]
# ### Last 15 Performances (Unweighted)

# %%
stats = ['fg', 'fga', 'fg_perc', '2p', '2pa', '2p_perc', '3p', '3pa', '3p_perc', 'efg_perc', 'ast', 'ast_perc']
dates = ['_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '_10', '_11', '_12', '_13', '_14', '_15']
trends = ['_trend_3', '_trend_5', '_trend_10']
cols = ['date', 'visitor', 'home', 'team', 'target'] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, dates))] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, trends))]

last_15_games_unweighted = last_15_games[cols].copy()

for stat in stats:
    last_15_games_unweighted[stat] = 0
    for date in dates:
        last_15_games_unweighted[stat] = last_15_games_unweighted[stat] + last_15_games_unweighted[stat + date]
    
    last_15_games_unweighted[stat] = last_15_games_unweighted[stat] / len(dates)

last_15_games_unweighted = last_15_games_unweighted.dropna(axis=0)
last_15_games_unweighted.head()
# Out:
#          date                 visitor           home           team  target  \
# 15 2006-12-02      Washington Wizards  Chicago Bulls  Chicago Bulls      30
# 16 2006-12-04          Boston Celtics  Chicago Bulls  Chicago Bulls      25
# 17 2006-12-06      Philadelphia 76ers  Chicago Bulls  Chicago Bulls      27
# 18 2006-12-08         Toronto Raptors  Chicago Bulls  Chicago Bulls      24
# 19 2006-12-09  Minnesota Timberwolves  Chicago Bulls  Chicago Bulls      22
#
#     fg_1  fg_2  fg_3  fg_4  fg_5  fg_6  fg_7  fg_8  fg_9  fg_10  fg_11  fg_12  \
# 15  41.0  37.0  38.0  40.0  39.0  27.0  33.0  35.0  39.0   31.0   40.0   46.0
# 16  41.0  41.0  37.0  38.0  40.0  39.0  27.0  33.0  35.0   39.0   31.0   40.0
# 17  37.0  41.0  41.0  37.0  38.0  40.0  39.0  27.0  33.0   35.0   39.0   31.0
# 18  48.0  37.0  41.0  41.0  37.0  38.0  40.0  39.0  27.0   33.0   35.0   39.0
# 19  35.0  48.0  37.0  41.0  41.0  37.0  38.0  40.0  39.0   27.0   33.0   35.0
#
#     fg_13  fg_14  fg_15  fga_1  fga_2  fga_3  fga_4  fga_5  fga_6  fga_7  \
# 15   32.0   37.0   39.0   86.0   84.0   84.0   73.0   90.0   80.0   72.0
# 16   46.0   32.0   37.0   81.0   86.0   84.0   84.0   73.0   90.0   80.0
# 17   40.0   46.0   32.0   79.0   81.0   86.0   84.0   84.0   73.0   90.0
#
#     3p_perc_4  3p_perc_5  3p_perc_6  3p_perc_7  3p_perc_8  3p_perc_9  \
# 15      0.462      0.333      0.389      0.556      0.350      0.300
# 16      0.294      0.462      0.333      0.389      0.556      0.350
# 17      0.467      0.294      0.462      0.333      0.389      0.556
# 18      0.571      0.467      0.294      0.462      0.333      0.389
# 19      0.391      0.571      0.467      0.294      0.462      0.333
#
#     3p_perc_10  3p_perc_11  3p_perc_12  3p_perc_13  3p_perc_14  3p_perc_15  \
# 15       0.400       0.438       0.333       0.222       0.300       0.538
# 16       0.300       0.400       0.438       0.333       0.222       0.300
# 17       0.350       0.300       0.400       0.438       0.333       0.222
# 18       0.556       0.350       0.300       0.400       0.438       0.333
# 19       0.389       0.556       0.350       0.300       0.400       0.438
#
#     efg_perc_1  efg_perc_2  efg_perc_3  efg_perc_4  efg_perc_5  efg_perc_6  \
# 15       0.547       0.482       0.482       0.589       0.478       0.381
# 16       0.562       0.547       0.482       0.482       0.589       0.478
# 17       0.494       0.562       0.547       0.482       0.482       0.589
# 18       0.654       0.494       0.562       0.547       0.482       0.482
# 19       0.507       0.654       0.494       0.562       0.547       0.482
#
#     efg_perc_7  efg_perc_8  efg_perc_9  efg_perc_10  efg_perc_11  efg_perc_12  \
# 15       0.493       0.487       0.471        0.420        0.478        0.571
# 16       0.381       0.493       0.487        0.471        0.420        0.478
# 17       0.478       0.381       0.493        0.487        0.471        0.420
# 18       0.589       0.478       0.381        0.493        0.487        0.471
# 19       0.482       0.589       0.478        0.381        0.493        0.487
#
#     efg_perc_13  efg_perc_14  efg_perc_15  ast_1  ast_2  ast_3  ast_4  ast_5  \
# 15        0.423        0.488        0.538   25.0   22.0   22.0   21.0   22.0
# 16        0.571        0.423        0.488   28.0   25.0   22.0   22.0   21.0
# 17        0.478        0.571        0.423   23.0   28.0   25.0   22.0   22.0
# 18        0.420        0.478        0.571   29.0   23.0   28.0   25.0   22.0
# 19        0.471        0.420        0.478   22.0   29.0   23.0   28.0   25.0
#
#     ast_6  ast_7  ast_8  ast_9  ast_10  ast_11  ast_12  ast_13  ast_14  \
# 15   17.0   18.0   15.0   18.0    20.0    27.0    33.0    18.0    21.0
# 16   22.0   17.0   18.0   15.0    18.0    20.0    27.0    33.0    18.0
# 17   21.0   22.0   17.0   18.0    15.0    18.0    20.0    27.0    33.0
# 18   22.0   21.0   22.0   17.0    18.0    15.0    18.0    20.0    27.0
# 19   22.0   22.0   21.0   22.0    17.0    18.0    15.0    18.0    20.0
#
#     ast_15  ast_perc_1  ast_perc_2  ast_perc_3  ast_perc_4  ast_perc_5  \
# 15    22.0       0.610       0.595       0.579       0.525       0.564
# 16    21.0       0.683       0.610       0.595       0.579       0.525
# 17    18.0       0.622       0.683       0.610       0.595       0.579
# 18    33.0       0.604       0.622       0.683       0.610       0.595
# 19    27.0       0.629       0.604       0.622       0.683       0.610
#
#     ast_perc_6  ast_perc_7  ast_perc_8  ast_perc_9  ast_perc_10  ast_perc_11  \
# 15       0.630       0.545       0.429       0.462        0.645        0.675
# 19          0.543438           0.241138    10.013936    10.392357
#
#     ast_trend_10  ast_perc_trend_3  ast_perc_trend_5  ast_perc_trend_10  \
# 15      7.605805          0.004645         -0.107696          -0.198389
# 16      8.018628          0.198722          0.025546          -0.177115
# 17      8.276642          0.249107          0.134154          -0.087541
# 18      8.999081          0.237910          0.162146           0.010430
# 19      9.205492          0.137140          0.200215           0.057456
#
#            fg        fga   fg_perc         2p        2pa   2p_perc        3p  \
# 15  36.933333  82.000000  0.450733  30.733333  66.333333  0.463467  6.200000
# 16  37.066667  82.133333  0.451533  30.733333  65.800000  0.467933  6.333333
# 17  37.066667  81.933333  0.452667  30.866667  65.733333  0.470667  6.200000
# 18  38.133333  81.933333  0.466333  31.666667  65.466667  0.484733  6.466667
# 19  37.400000  81.200000  0.461800  30.933333  64.533333  0.481400  6.466667
#
#           3pa   3p_perc  efg_perc        ast  ast_perc
# 15  15.666667  0.396867  0.488533  21.400000  0.578000
# 16  16.333333  0.387067  0.490133  21.800000  0.585933
# 17  16.200000  0.381867  0.490533  21.933333  0.589533
# 18  16.466667  0.397867  0.505933  22.666667  0.592333
# 19  16.666667  0.394200  0.501667  21.933333  0.586467

# %% [markdown]
# ### Last 15 Performances (Weighted)

# %%
stats = ['fg', 'fga', 'fg_perc', '2p', '2pa', '2p_perc', '3p', '3pa', '3p_perc', 'efg_perc', 'ast', 'ast_perc']
dates = ['_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '_10', '_11', '_12', '_13', '_14', '_15']
trends = ['_trend_3', '_trend_5', '_trend_10']
cols = ['date', 'visitor', 'home', 'team', 'target'] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, dates))] + \
    [tup[0] + tup[1] for tup in list(itertools.product(stats, trends))]

last_15_games_weighted = last_15_games[cols].copy()

for stat in stats:
    last_15_games_weighted[stat] = 0
    for date in dates:
        weight = ((int(date.strip('_')) - 1) // 5) + 1
        last_15_games_weighted[stat] = (last_15_games_weighted[stat] + last_15_games_weighted[stat + date]) * weight
    
    last_15_games_weighted[stat] = last_15_games_weighted[stat] / len(dates)

last_15_games_weighted = last_15_games_weighted.dropna(axis=0)
last_15_games_weighted.head()
# Out:
#          date                 visitor           home           team  target  \
# 15 2006-12-02      Washington Wizards  Chicago Bulls  Chicago Bulls      30
# 16 2006-12-04          Boston Celtics  Chicago Bulls  Chicago Bulls      25
# 17 2006-12-06      Philadelphia 76ers  Chicago Bulls  Chicago Bulls      27
# 18 2006-12-08         Toronto Raptors  Chicago Bulls  Chicago Bulls      24
# 19 2006-12-09  Minnesota Timberwolves  Chicago Bulls  Chicago Bulls      22
#
#     fg_1  fg_2  fg_3  fg_4  fg_5  fg_6  fg_7  fg_8  fg_9  fg_10  fg_11  fg_12  \
# 15  41.0  37.0  38.0  40.0  39.0  27.0  33.0  35.0  39.0   31.0   40.0   46.0
# 16  41.0  41.0  37.0  38.0  40.0  39.0  27.0  33.0  35.0   39.0   31.0   40.0
# 17  37.0  41.0  41.0  37.0  38.0  40.0  39.0  27.0  33.0   35.0   39.0   31.0
# 18  48.0  37.0  41.0  41.0  37.0  38.0  40.0  39.
# 15    16.0    15.0     9.0    20.0    13.0      0.571      0.467      0.294
# 16    15.0    16.0    15.0     9.0    20.0      0.391      0.571      0.467
# 17    10.0    15.0    16.0    15.0     9.0      0.222      0.391      0.571
# 18    20.0    10.0    15.0    16.0    15.0      0.462      0.222      0.391
# 19     9.0    20.0    10.0    15.0    16.0      0.278      0.462      0.222
#
#     3p_perc_4  3p_perc_5  3p_perc_6  3p_perc_7  3p_perc_8  3p_perc_9  \
# 15      0.462      0.333      0.389      0.556      0.350      0.300
# 16      0.294      0.462      0.333      0.389      0.556      0.350
# 17      0.467      0.294      0.462      0.333      0.389      0.556
# 18      0.571      0.467      0.294      0.462      0.333      0.389
# 19      0.391      0.571      0.467      0.294      0.462      0.333
#
#     3p_perc_10  3p_perc_11  3p_perc_12  3p_perc_13  3p_perc_14  3p_perc_15  \
# 15       0.400       0.438       0.333       0.222       0.300       0.538
# 16       0.300       0.400       0.438       0.333       0.222       0.300
# 17       0.350       0.300       0.400       0.438       0.333       0.222
# 18       0.556       0.350       0.300       0.400       0.438       0.333
# 19       0.389       0.556       0.350       0.300       0.400       0.438
#
#     efg_perc_1  efg_perc_2  efg_perc_3  efg_perc_4  efg_perc_5  efg_perc_6  \
# 15       0.547       0.482       0.482       0.589       0.478       0.381
# 16       0.562       0.547       0.482       0.482       0.589       0.478
# 17       0.494       0.562       0.547       0.482       0.482       0.589
# 18       0.654       0.494       0.562       0.547       0.482       0.482
# 19       0.507       0.654       0.494       0.562       0.547       0.482
#
#     efg_perc_7  efg_perc_8  efg_perc_9  efg_perc_10  efg_perc_11  efg_perc_12  \
# 15       0.493       0.487       0.471        0.420        0.478        0.571
# 16       0.381       0.493       0.487        0.471        0.420        0.478
# 17       0.478       0.381       0.493        0.487        0.471        0.420
# 18       0.589       0.478       0.381        0.493        0.487        0.471
# 19       0.482       0.589       0.478        0.381        0.493        0.487
#
#     efg_perc_13  efg_perc_14  efg_perc_15  ast_1  ast_2  ast_3  ast_4  ast_5  \
# 15        0.423        0.488        0.538   25.0   22.0   22.0   21.0   22.0
# 16        0.571        0.423        0.488   28.0   25.0   22.0   22.0   21.0
# 17        0.478        0.571        0.423   23.0   28.0   25.0   22.0   22.0
# 18        0.420        0.478        0.571   29.0   23.0   28.0   25.0   22.0
# 19        0.471        0.420        0.478   22.0   29.0   23.0   28.0   25.0
#
#     ast_6  ast_7  ast_8  ast_9  ast_10  ast_11  ast_12  ast_13  ast_14  \
# 15   17.0   18.0   15.0   18.0    20.0    27.0    33.0    18.0    21.0
# 16   22.0   17.0   18.0   15.0    18.0    20.0    27.0    33.0    18.0
# 17   21.0   22.0   17.0   18.0    15.0    18.0    20.0    27.0    33.0
# 18   22.0   21.0   22.0   17.0    18.0    15.0    18.0    20.0    27.0
# 19   22.0   22.0   21.0   22.0    17.0    18.0    15.0    18.0    20.0
#
#     ast_15  ast_perc_1  ast_perc_2  ast_perc_3  ast_perc_4  ast_perc_5  \
# 15    22.0       0.610       0.595       0.579       0.525       0.564
# 16    21.0       0.683       0.610       0.595       0.579       0.525
# 19        -0.209262         0.039390          0.047532          0.533705
#
#     efg_perc_trend_5  efg_perc_trend_10  ast_trend_3  ast_trend_5  \
# 15          0.223962          -0.056009     9.153890     8.844273
# 16          0.368242           0.065941    10.185946     9.463506
# 17          0.205068           0.085694    10.357955     9.669918
# 18          0.500498           0.229115    11.045993    10.392357
# 19          0.543438           0.241138    10.013936    10.392357
#
#     ast_trend_10  ast_perc_trend_3  ast_perc_trend_5  ast_perc_trend_10  \
# 15      7.605805          0.004645         -0.107696          -0.198389
# 16      8.018628          0.198722          0.025546          -0.177115
# 17      8.276642          0.249107          0.134154          -0.087541
# 18      8.999081          0.237910          0.162146           0.010430
# 19      9.205492          0.137140          0.200215           0.057456
#
#           fg       fga    fg_perc        2p       2pa    2p_perc       3p  \
# 15  132690.0  296881.4  1622.5060  106621.0  234464.4  1648.4176  26069.0
# 16  137976.8  298155.8  1680.7910  110452.4  231758.8  1733.3524  27524.4
# 17  139091.2  295443.0  1709.3698  113171.4  229906.8  1791.6276  25919.8
# 18  144560.6  295116.8  1779.0116  118916.2  231292.4  1868.2916  25644.4
# 19  143153.6  291341.0  1782.4474  117914.4  226840.2  1889.1868  25239.2
#
#         3pa    3p_perc   efg_perc      ast   ast_perc
# 15  62417.0  1535.7506  1780.9640  75962.6  2079.9252
# 16  66397.0  1520.2554  1848.0064  81414.6  2135.9618
# 17  65536.2  1439.9382  1868.2566  83124.0  2163.2750
# 18  63824.4  1462.2570  1936.6358  87619.8  2193.2616
# 19  64500.8  1421.5212  1939.1258  88064.4  2227.9464

# %% [markdown]
# ## Correlations of performances (last 1, last 5, last 10)

# %%
corr_df = pd.DataFrame()

# Correlations for last 15 game stats vs 3pt made (unweighted)
for col in last_15_games_weighted.iloc[:, 4:]:
    corr_p = pearsonr(last_15_games_weighted['target'], last_15_games_weighted[col])
    row = {'last': '15_weighted', 'stat': col, 'corr': round(corr_p[0], 2), 'p-value': round(corr_p[1], 2)}
    corr_df = corr_df.append(row, ignore_index=True)

# Correlations for last 15 game stats vs 3pt made (unweighted)
for col in last_15_games_unweighted.iloc[:, 4:]:
    corr_p = pearsonr(last_15_games_unweighted['target'], last_15_games_unweighted[col])
    row = {'last': '15_unweighted', 'stat': col, 'corr': round(corr_p[0], 2), 'p-value': round(corr_p[1], 2)}
    corr_df = corr_df.append(row, ignore_index=True)

# Correlations for last 10 game stats vs 3pt made 
for col in last_10_games.iloc[:, 4:]:
    corr_p = pearsonr(last_10_games['target'], last_10_games[col])
    row = {'last': 10, 'stat': col, 'corr': round(corr_p[0], 2), 'p-value': round(corr_p[1], 2)}
    corr_df = corr_df.append(row, ignore_index=True)
    
# Correlations for last 10 game stats vs 3pt made 
for col in last_5_games.iloc[:, 4:]:
    corr_p = pearsonr(last_5_games['target'], last_5_games[col])
    row = {'last': 5, 'stat': col, 'corr': round(corr_p[0], 2), 'p-value': round(corr_p[1], 2)}
    corr_df = corr_df.append(row, ignore_index=True)
    
# Correlations for last game stats vs 3pt made 
for col in last_game.iloc[:, 4:]:
    corr_p = pearsonr(last_game['target'], last_game[col])
    row = {'last': 1, 'stat': col, 'corr': round(corr_p[0], 2), 'p-value': round(corr_p[1], 2)}
    corr_df = corr_df.append(row, ignore_index=True)
    
# Print each correlation
for stat in stats + [tup[0] + tup[1] for tup in list(itertools.product(stats, trends))] + ['target']:
    print(f'Stat: {stat}')
    print(corr_df[(corr_df['stat'] == stat) & (corr_df['p-value'] < .05)].set_index(['last']).drop(['stat'], axis=1))
    print('\n')
# Out:
# Stat: fg
#                corr  p-value
# last
# 15_weighted    0.22      0.0
# 15_unweighted  0.24      0.0
# 10             0.23      0.0
# 5              0.21      0.0
# 1              0.13      0.0
#
#
# Stat: fga
#                corr  p-value
# last
# 15_weighted    0.20      0.0
# 15_unweighted  0.21      0.0
# 10             0.20      0.0
# 5              0.19      0.0
# 1              0.12      0.0
#
#
# Stat: fg_perc
#                corr  p-value
# last
# 15_weighted    0.10      0.0
# 15_unweighted  0.11      0.0
# 10             0.11      0.0
# 5              0.09      0.0
# 1              0.05      0.0
#
#
# Stat: 2p
#                corr  p-value
# last
# 15_unweighted -0.02     0.00
# 10            -0.01     0.03
#
#
# Stat: 2pa
#                corr  p-value
# last
# 15_weighted   -0.13      0.0
# 15_unweighted -0.14      0.0
# 10            -0.14      0.0
# 5             -0.12      0.0
# 1             -0.08      0.0
#
#
# Stat: 2p_perc
#                corr  p-value
# last
# 15_weighted    0.18      0.0
# 15_unweighted  0.21      0.0
# 10             0.19      0.0
# 5              0.17      0.0
# 1              0.10      0.0
#
#
# Stat: 3p
#                corr  p-value
# last
# 15_weighted    0.23      0.0
# 15_unweighted  0.23      0.0
# 10             0.23      0.0
# 5              0.22      0.0
# 1              0.16      0.0
#
#
# Stat: 3pa
#                corr  p-value
# last
# 15_weighted    0.23      0.0
# 15_unweighted  0.23      0.0
# 10             0.23      0.0
# 5              0.23      0.0
# 1              0.20      0.0
#
#
# Stat: 3p_perc
#                corr  p-value
# last
# 15_weighted    0.06      0.0
# 15_unweighted  0.07      0.0
# 10             0.06      0.0
# 5              0.05      0.0
# 1              0.02      0.0
#
#
# Stat: efg_perc
#                corr  p-value
# last
# 15_weighted    0.18      0.0
# 15_unweighted  0.20      0.0
# 10             0.19      0.0
# 5              0.17      0.0
# 1              0.09      0.0
#
#
# Stat: ast
#                corr  p-value
# last
# 15_weighted    0.18      0.0
# 15_unweighted  0.19      0.0
# 10             0.18      0.0
# 5              0.17      0.0
# 1              0.10      0.0
#
#
# Stat: ast_perc
#                corr  p-value
# last
# 15_weighted    0.06      0.0
# 15_unweighted  0.07      0.0
# 10             0.06      0.0
# 5              0.06      0.0
# 1              0.03      0.0
#
#
# Stat: fg_trend_3
#                corr  p-value
# last
# 15_weighted    0.09      0.0
# 15_unweighted  0.09      0.0
# 10             0.09      0.0
# 5              0.09      0.0
# 1              0.09      0.0
#
#
# Stat: fg_trend_5
#                corr  p-value
# last
# 15_weighted     0.1      0.0
# 15_unweighted   0.1      0.0
# 10              0.1      0.0
# 5               0.1      0.0
# 1               0.1      0.0
#
#
# Stat: fg_trend_10
#                corr  p-value
# last
# 15_weighted     0.1      0.0
# 15_unweighted   0.1      0.0
# 10              0.1      0.0
# 5               0.1      0.0
# 1               0.1      0.0
#
#
# Stat: fga_trend_3
#                corr  p-value
# last
# 15_weighted    0.11      0.0
# 15_unweighted  0.11      0.0
# 10             0.11      0.0
# 5              0.11      0.0
# 1              0.11      0.0
#
#
# Stat: fga_trend_5
#                corr  p-value
# last
# 15_weighted    0.11      0.0
# 15_unweighted  0.11      0.0
# 10             0.11      0.0
# 5              0.11      0.0
# 1              0.11      0.0
#
#
# Stat: fga_trend_10
#                corr  p-value
# last
# 15_weighted    0.11      0.0
# 15_unweighted  0.11      0.0
# 10             0.11      0.0
# 5              0.11      0.0
# 1              0.11      0.0
#
#
# Stat: fg_perc_trend_3
#                corr  p-value
# last
# 15_weighted   -0.02      0.0
# 15_unweighted -0.02      0.0
# 10            -0.02      0.0
# 5             -0.02      0.0
# 1             -0.02      0.0
#
#
# Stat: fg_perc_trend_5
#                corr  p-value
# last
# 15_weighted   -0.03      0.0
# 15_unweighted -0.03      0.0
# 10            -0.03      0.0
# 5             -0.03      0.0
# 1             -0.03      0.0
#
#
# Stat: fg_perc_trend_10
#                corr  p-value
# last
# 15_weighted   -0.05      0.0
# 15_unweighted -0.05      0.0
# 10            -0.05      0.0
# 5             -0.05      0.0
# 1             -0.05      0.0
#
#
# Stat: 2p_trend_3
#                corr  p-value
# last
# 15_weighted   -0.01     0.01
# 15_unweighted -0.01     0.01
# 10            -0.01     0.01
# 5             -0.01     0.01
# 1             -0.01     0.01
#
#
# Stat: 2p_trend_5
#                corr  p-value
# last
# 15_weighted   -0.02      0.0
# 15_unweighted -0.02      0.0
# 10            -0.02      0.0
# 5             -0.02      0.0
# 1             -0.02      0.0
#
#
# Stat: 2p_trend_10
#                corr  p-value
# last
# 15_weighted   -0.03      0.0
# 15_unweighted -0.03      0.0
# 10            -0.03      0.0
# 5             -0.03      0.0
# 1             -0.03      0.0
#
#
# Stat: 2pa_trend_3
#                corr  p-value
# last
# 15_weighted    -0.1      0.0
# 15_unweighted  -0.1      0.0
# 10             -0.1      0.0
# 5              -0.1      0.0
# 1              -0.1      0.0
#
#
# Stat: 2pa_trend_5
#                corr  p-value
# last
# 15_weighted   -0.11      0.0
# 15_unweighted -0.11      0.0
# 10            -0.11      0.0
# 5             -0.11      0.0
# 1             -0.11      0.0
#
#
# Stat: 2pa_trend_10
#                corr  p-value
# last
# 15_weighted   -0.13      0.0
# 15_unweighted -0.13      0.0
# 10            -0.13      0.0
# 5             -0.13      0.0
# 1             -0.13      0.0
#
#
# Stat: 2p_perc_trend_3
#                corr  p-value
# last
# 15_weighted   -0.02      0.0
# 15_unweighted -0.02      0.0
# 10            -0.02      0.0
# 5             -0.02      0.0
# 1             -0.02      0.0
#
#
# Stat: 2p_perc_trend_5
#                corr  p-value
# last
# 15_weighted   -0.02      0.0
# 15_unweighted -0.02      0.0
# 10            -0.02      0.0
# 5             -0.02      0.0
# 1             -0.02      0.0
#
#
# Stat: 2p_perc_trend_10
#                corr  p-value
# last
# 15_weighted   -0.04      0.0
# 15_unweighted -0.04      0.0
# 10            -0.04      0.0
# 5             -0.04      0.0
# 1             -0.04      0.0
#
#
# Stat: 3p_trend_3
#                corr  p-value
# last
# 15_weighted    0.11      0.0
# 15_unweighted  0.11      0.0
# 10             0.11      0.0
# 5              0.11      0.0
# 1              0.11      0.0
#
#
# Stat: 3p_trend_5
#                corr  p-value
# last
# 15_weighted    0.13      0.0
# 15_unweighted  0.13      0.0
# 10             0.13      0.0
# 5              0.13      0.0
# 1              0.13      0.0
#
#
# Stat: 3p_trend_10
#                corr  p-value
# last
# 15_weighted    0.14      0.0
# 15_unweighted  0.14      0.0
# 10             0.14      0.0
# 5              0.14      0.0
# 1              0.14      0.0
#
#
# Stat: 3pa_trend_3
#                corr  p-value
# last
# 15_weighted    0.16      0.0
# 15_unweighted  0.16      0.0
# 10             0.16      0.0
# 5              0.16      0.0
# 1              0.16      0.0
#
#
# Stat: 3pa_trend_5
#                corr  p-value
# last
# 15_weighted    0.17      0.0
# 15_unweighted  0.17      0.0
# 10             0.17      0.0
# 5              0.17      0.0
# 1              0.17      0.0
#
#
# Stat: 3pa_trend_10
#                corr  p-value
# last
# 15_weighted    0.17      0.0
# 15_unweighted  0.17      0.0
# 10             0.17      0.0
# 5              0.17      0.0
# 1              0.17      0.0
#
#
# Stat: 3p_perc_trend_3
#                corr  p-value
# last
# 15_weighted   -0.02      0.0
# 15_unweighted -0.02      0.0
# 10            -0.02      0.0
# 5             -0.02      0.0
# 1             -0.02      0.0
#
#
# Stat: 3p_perc_trend_5
#                corr  p-value
# last
# 15_weighted   -0.02      0.0
# 15_unweighted -0.02      0.0
# 10            -0.02      0.0
# 5             -0.02      0.0
# 1             -0.02      0.0
#
#
# Stat: 3p_perc_trend_10
#                corr  p-value
# last
# 15_weighted   -0.04      0.0
# 15_unweighted -0.04      0.0
# 10            -0.04      0.0
# 5             -0.04      0.0
# 1             -0.04      0.0
#
#
# Stat: efg_perc_trend_3
#                corr  p-value
# last
# 15_weighted   -0.02      0.0
# 15_unweighted -0.02      0.0
# 10            -0.02      0.0
# 5             -0.02      0.0
# 1             -0.02      0.0
#
#
# Stat: efg_perc_trend_5
#                corr  p-value
# last
# 15_weighted   -0.03      0.0
# 15_unweighted -0.03      0.0
# 10            -0.03      0.0
# 5             -0.03      0.0
# 1             -0.03      0.0
#
#
# Stat: efg_perc_trend_10
#                corr  p-value
# last
# 15_weighted   -0.05      0.0
# 15_unweighted -0.05      0.0
# 10            -0.05      0.0
# 5             -0.05      0.0
# 1             -0.05      0.0
#
#
# Stat: ast_trend_3
#                corr  p-value
# last
# 15_weighted    0.08      0.0
# 15_unweighted  0.08      0.0
# 10             0.08      0.0
# 5              0.08      0.0
# 1              0.08      0.0
#
#
# Stat: ast_trend_5
#                corr  p-value
# last
# 15_weighted    0.09      0.0
# 15_unweighted  0.09      0.0
# 10             0.09      0.0
# 5              0.09      0.0
# 1              0.09      0.0
#
#
# Stat: ast_trend_10
#                corr  p-value
# last
# 15_weighted     0.1      0.0
# 15_unweighted   0.1      0.0
# 10              0.1      0.0
# 5               0.1      0.0
# 1               0.1      0.0
#
#
# Stat: ast_perc_trend_3
#                corr  p-value
# last
# 15_weighted    0.01     0.01
# 15_unweighted  0.01     0.01
# 10             0.01     0.01
# 5              0.01     0.01
# 1              0.01     0.01
#
#
# Stat: ast_perc_trend_5
#                corr  p-value
# last
# 15_weighted    0.02      0.0
# 15_unweighted  0.02      0.0
# 10             0.02      0.0
# 5              0.02      0.0
# 1              0.02      0.0
#
#
# Stat: ast_perc_trend_10
#                corr  p-value
# last
# 15_weighted    0.02      0.0
# 15_unweighted  0.02      0.0
# 10             0.02      0.0
# 5              0.02      0.0
# 1              0.02      0.0
#
#
# Stat: target
#                corr  p-value
# last
# 15_weighted     1.0      0.0
# 15_unweighted   1.0      0.0
# 10              1.0      0.0
# 5               1.0      0.0
# 1               1.0      0.0
